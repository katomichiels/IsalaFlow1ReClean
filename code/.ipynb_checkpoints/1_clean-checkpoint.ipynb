# %%
import sys
sys.path.append('C:/Users/LUCP12511/Documents/PhD Kato/ISALA/Repos/BIU-master') # Modify this to where you have downloaded the BIU library
#import biu
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
plt.rcParams['svg.fonttype'] = 'none'

import seaborn as sns
import scipy

# install rdmpy with pip install git+https://github.com/thiesgehrmann/rdmpy
#from rdmpy import RDM
#RDM.meta(source="repos/LunaQuestionnaire/clean.ipynb")

# %% [markdown]
# # Cleaned questions overview table
#
# |Question Number|Question identifier|Clean question identifier|
# |---------------|-------------------|-------------------------|
# |   |   | Reproductive.Cycle.Phase|
# |Q1.Q52.2.|Heeft dit te maken met één van de onderstaande mogelijkheden? - Selected Choice|Reproductive.PeriMenopause|
# |Q1.Q4.|Mijn partner(s) is/zijn...|Lifestyle.Partner.Is|
# | |uitgedragen|Reproductive.Pregnancy|
# |Q1.Q21.|Rook je? Geef ook op hoeveel sigaretten je per dag rook(te) - Selected Choice|Lifestyle.Drugs.Current_smoker|
# |Q1.Q22.|Gebruik je drugs (exclusief alcohol)? Gelieve ook aan te geven welke. Deze informatie wordt pseudoniem verwerkt. Wij hebben het grootste respect voor jou en voor je privacy. - Selected Choice|Lifestyle.Drugs.Current_druguser|
# |Q1.Q49.|Heb je ooit actief geprobeerd om zwanger te worden?|Reproductive.Pregnancy.Attempted|
# |Q2.Q24.|Geef je op dit moment borstvoeding?|Reproductive.Breastfeeding|
# |Q1.Q29_4.|Hoe regelmatig heb je de onderstaande zaken gegeten of gedronken in de afgelopen 3 maanden? - Vlees|Nutrition.EatsMeat|
# |Q1.Q29_6.|Hoe regelmatig heb je de onderstaande zaken gegeten of gedronken in de afgelopen 3 maanden? - Vis|Nutrition.EatsFish|
# |Q1.Q29_5.|Hoe regelmatig heb je de onderstaande zaken gegeten of gedronken in de afgelopen 3 maanden? - Dierlijke producten (eieren, kaas, gelatine,...)|Nutrition.EatsAnimals|
# | | |Nutrition.Vgetarian|
# | | |Nutrition.Pescetarian|
# | | |Nutrition.Vegan|
# |Q1.Q15.|Hoe zou je het gebied waar je nu woont omschrijven?|Environment.Urban|
# |Q1.Q15.|Hoe zou je het gebied waar je nu woont omschrijven?|Environment.Coutryside|
# |Q1.Q9.|In welk(e) land(en) heb je gewoond tot en met je derde levensjaar? Indien dit enkel België is, mag je het ook opgeven.|Environment.Belgium.First3Years|
# |Q1.Q47.|Heb je de afgelopen drie maanden één of meerdere seksuele\npartner(s) gehad? - Selected Choice|Lifestyle.Partner.OneVsSingle|
# |Q1.Q47.|Heb je de afgelopen drie maanden één of meerdere seksuele\npartner(s) gehad? - Selected Choice|Lifestyle.Partner.OneVsMany|
# |Q2.Q7.|Hoe groot is je aandeel aan het gezinsinkomen?|Environment.Economic.HouseholdContribution|
# |Q2.Q4.|Kan je maandelijks rondkomen met de som van totaal beschikbaar gezinsinkomen (alles inbegrepen*)?|Environment.Economic.FinancialDifficulties|
# |Q1.Q50.|Hoeveel keer was je al zwanger?|Reproductive.Pregnancy.n|
# |Q1.Q1.|Geslacht - Selected Choice|General.Gender|
# |Q1.Q2_1.|Enkele algemene vragen over jou: - Leeftijd (jaar)|General.Age|
# |Q1.Q2_2.|Enkele algemene vragen over jou: - Lengte (cm)|General.Height|
# |Q1.Q2_3.|Enkele algemene vragen over jou: - Gewicht (kg)|General.Weight|
# | | |General.BMI

# %% [markdown]
# # Functions

# %%
def freq(lst, key=lambda x: x):
    """
    Count the number of occurances in a list.
    Input:
        lst: an iterable list
        key: a callable function that is called upon the value, the return value of which is counted
    
    Output: Dictionary with count of each item
    """
    F = {}
    for item in lst:
        if pd.isna(item):
            item = None
        #fi
        F[key(item)] = F.get(key(item), 0) + 1
    #efor
    return F


def qerf(lst, key=lambda x: x):
    """
    Return the frequency of objects in a list, indexed by their frequency, rather than by the item itself.
    parameters:
    -----------
    lst: list[obj]
        List of hashable objects
    key: callable(obj)
        A function which will be called upon the objects in the list
        
    example:
    qerf([1,2,3,3,4,4,4])
     { 1: [1,2],
       2: [3],
       3: [4]
       }
    """
    f = freq(lst, key)
    q = { }
    for (i,c) in f.items():
        q[c] = q.get(c,[]) + [i]
    #efor
    return q

# %% [markdown]
# # Load the Isala Flow 1 questionnaire data

# %%
#with RDM('../data/processed/merged_questionnaires.pkl', 'r', nouser=True) as ifd:
#    Qraw = pd.read_pickle(ifd)
#ewith
Qraw = pd.read_pickle("../data/processed/merged_questionnaires.rdm_thies_2024-08-09T11-49-27-140516.pkl")
    
#Qraw = pd.read_excel('../data/processed/merged_from_sharepoint_flow1_all_questionnaires.20231031.xlsx')

# %% [markdown]
# ## Search for questions
# Type in words that are part of a question in order to get back the names of matching columns

# %%
from ipywidgets import interact, interactive, fixed, interact_manual
## Interactive questionnaire search
def search_questionnaire(query):
    if len(query) < 2:
        return None
    #fi
    return Qraw[[ x for x in Qraw.columns if query.lower() in x.lower() ]].transpose()
#edef

_ = interact(search_questionnaire, query='')
# Out:
# interactive(children=(Text(value='', description='query'), Output()), _dom_classes=('widget-interact',))

# %% [markdown]
# ## Prepare the cleaned dataframe

# %%
QC = Qraw[['Q0.Deelnemersnummer']].rename(columns={'Q0.Deelnemersnummer':'IsalaID'}).copy()

# %% [markdown]
# # Clean questions

# %% [markdown]
# ## General

# %% [markdown]
# ### Gender

# %%
#Sex
def clean_gender(val):
    if pd.isna(val):
        return None
    elif 'Vrouw' in val:
        return 'Vrouw'
    elif 'Anders' in val:
        return 'Other'
    else:
        return None
    #fi
#edef
QC['General.Gender'] = Qraw["Q1.Q1.[Geslacht - Selected Choice]"].apply(clean_gender)

# %% [markdown]
# ### Age

# %%
#Age
def clean_age(x): 
    if pd.isna(x):
        return None
    elif str(x).isnumeric():
        if x <= 200:
            return int(x)
        elif x > 200:
            return int(2020 - x)
        #fi
    else:
        return None
    #fi
#edef
QC['General.Age'] = Qraw["Q1.Q2_1.[Enkele algemene vragen over jou: - Leeftijd (jaar)]"].apply(clean_age)

# %% [markdown]
# ### Height

# %%
#Height
def clean_height(x): 
    if pd.isna(x):
        return None
    elif str(x).isnumeric():
        if x > 3:
            return int(x)
        elif x <= 3:
            return int(x * 100)
        #fi
    else:
        return None
    #fi
#edef
QC['General.Height'] = Qraw["Q1.Q2_2.[Enkele algemene vragen over jou: - Lengte (cm)]"].apply(clean_height)

# %% [markdown]
# ### Weight

# %%
#Weight

def clean_weight(val):
    if pd.isna(val):
        return None
    elif str(val).isnumeric():
        return float(val)
    else:
        return None
    #fi
#edef

QC['General.Weight'] = Qraw['Q1.Q2_3.[Enkele algemene vragen over jou: - Gewicht (kg)]'].apply(clean_weight)

# %% [markdown]
# ### Education

# %%
map_main = {            #dictionnary for question Q1.Q18
'Postuniversitair: doctor': 'PhD',
 'Hogeschool: bachelor': 'College',
 'Universiteit: bachelor/master (kandidaat/licenciaat)': 'University',
 'Secundair onderwijs: KSO': 'Secondary education',
 'Secundair onderwijs: ASO': 'Secondary education',
 'Secundair onderwijs: BSO': 'Secondary education',
 'Secundair onderwijs: TSO': 'Secondary education',
 'Lagere school': 'Primary education',
 'Geen': 'No',
 '': None  
}

map_other = {  #If still studying: refers to highest completed degree
 'Hogeschool master': 'College',
 'Hogeschool - postgraduaat': 'College',
 'Master beeldende kunsten aan een hogeschool': 'College',
 'Hogeschool postgraduaat na bachelor': 'College',
 'professionele bachelor dans': 'College',
 'Hogeschool: master': 'College',
 'Dit is niet relevant ': None,
 'Hogeschool: bachelor -&gt; maar ik studeer nog verder voor een master': 'College',
 'International Baccalaureate (pre-universitair diploma, ongeveer gelijk aan ASO) ': 'Seconday education',
 '4de jaar kso': 'Primary education',
 'Hogeschool: lange type': 'College',
 'Specialisatiejaar hogeschool': 'College',
 'Hbo 5 verpleegkunde': 'College',
 'graduaat HBO5': 'College',
 'Graduaat (volwassenonderwijs)': 'College',
 'Bezig met universitaire opleiding, dus voorlopig alleen diploma van ASO secundair onderwijs': 'Seconday education',
 'Hoger beroepsonderwijs': 'College',
 'zorgkundige': 'Seconday education',
 'Hb05 verpleging ': 'College',
 'Hogeschool: Master': 'College',
 'Hbo-opleiding ': 'College',
 'Bachelor na bachelor': 'College',
 'HBO5': 'College',
 'deeltijds onderwijs': 'Secondary education',
 'MBO4': 'Seconday education',
 'bachelor na bachelor': 'College',
 'Hbo5': 'College',
 'Banaba': 'College',
 'Banaba Onco': 'College',
 'Manama': 'University',
 'Nog studerend: TSO middelbaar': 'Primary education',
 'Hbo': 'College',
 'Laatstejaars bachelor': 'Seconday education',
 'Hoger onderwijs kort type': 'College',
 'Technisch administratief': 'College', 
 'Hoger middelbaar kantoor/handel': "Secondary education",
 'Student op Universiteit Antwerpen (2de Bachelor momenteel) ': "Secondary education",
 'hogeschool: master': 'College',
 'HBO5 hoger beroepsonderwijs verpleegkunde ': 'College',
 'Gebrevetteerd verpleegkundige A2': 'College',
 'Hbo propedeuse ': "Secondary education",
 'MBO (middelbaar beroepsonderwijs = nederland niveau)': "Secondary education",
 'Momenteel bezig met Biomedische wetenschappen aan de universiteit Antwerpen, 2e bachelor': "Secondary education",
 'laatste jaar master momenteel': "University",
 'Hogeschool: bachelor - momenteel studeer ik voor mijn master (afstudeerjaar 2021)': 'College',
 'postgraduaat na master': "University",
 'Vwo diploma Nederland, bezig met hogeschool belgie': "Seconday education",
 'A2 verpleging': 'College',
 'Master na master': "University",
 'Graduaat': 'College',
 'Hbo5 verpleegkunde': 'College',
 'Hogeschool: lange type (master)': 'College',
 'verdergezet secundair ': "Secondary education",
 'Deeltijds kunstonderwijs': None,
 '4 jaar handel gestopt op 16 jaar': 'Primary education',
 'Mavo': 'Secondary education',
 'Volwassenenonderwijs ': 'College',
 'BanaBa en een postgraduaat opleiding UGent': 'College',
 'volwassenonderwijs syntra ': 'College',
 'HBOV verpleegkunde': 'College',
 'hogeschool beroepsopleiding': 'College',
 'Nog steeds student in een masteropleiding ': 'University',
 'Hogeschool: graduaat': 'College',
 'Master na Master ': 'University',
 '2 masters (universiteit)': 'University',
 'Hoger beroeps onderwijs; gegradueerde ': 'College',
 'Secundair na secundair (Se-n-Se)': 'Secunday education',
 'Bezig met bachelor opleiding vroedkunde': 'Secondary education',
 'BanaBa': 'College',
 'zit in mijn 1ste jaar bachelor aan de hogeschool ': 'Secondary education',
 'bezig ad hbo5 opleiding': 'Secondary education',
 'getuigschrift 6e middelbaar BSO': 'Secundary education',
 'Se-n-Se': 'Secundary education',
 'Ga nog naar school': None,
 'graduaat ': 'College',
 'Hogeschool ': 'College',
 'HBO verpleegkunde': 'College',
 'Havo': 'College',
 '2 de graad secundair tso': 'Primary education',
 'leercontract': None,
 'Secundair onderwijs door volwassenenonderwijs + certificaat webdesigner': 'Secundary education',
 'VWO': 'Secondary education',
 'BSO + 7e specialisatie=A2': 'Secondary education',
 'Diploma SLO opleiding ': 'College',
 'Ma na Ma': 'University',
 '7de jaar zorgkundige ': 'Secondary education',
 'Hbo5 ': 'College',
 'Mbo': 'Secondary education',
 'Volwassenonderwijs lerarendiploma ': 'College',
 'Graduaat ': 'College',
 'Hoger beroeps onderswijs': 'College',
 'Avondschool': None,
 'master na master': 'University',
 'Specialisatie 7e jaar na 6 jaar TSO': 'Secondary education',
 'Getuigschrift ': None,
 'Volwassenonderwijs ': None,
 'Hoger onderwijs van het korte type voor sociale promotie (hoktsp) Hoger onderwijs voor ': 'College',
 'HBO master': 'College',
 'Hoger beroeps onderwijs a2 verpleegkundige ': 'Seconday education',
 'Hoger onderwijs: Graduaat': 'College',
 'Hogeschoolcertificaat': 'College',
 'A2 verpleging ': 'Secondary education',
 'Hogeschool: bachelor & bachelor-na-bachelor': 'College',
 'MBO 4 Nederlands onderwijs': 'Secondary education',
 'HBO5 + SLO': 'College',
 'Volwassenonderwijs bedrijfsbeheer ': None,
 'MBO niv. 4': 'Secondary education',
 'Slo opleiding ': 'College',
 'graduaat': 'College',
 'Avondonderwijs': None,
 'postgraduaat': 'College',
 'Secundair diploma Amerika': 'Secondary education',
 'professionele master': 'College',
 'ManaMa': 'University',
 'Nederlandse opleiding MBO 4 juridisch medewerker ': 'College',
 'Master + banaba + postgraduaat': 'College',
 'Master-na-master (business school)': 'University',
 'Middelbare school kader Vmbo (Nederland)': 'Secondary education',
 'HBO graduaat verzekeringen + PCP statuut behaald via Febelfin (Overheid)': 'College',
 'Mbo 3': 'Secondary education',
 'Middelbaar beroeps onderwijs': 'Secondary education',
 'mbo': 'Secundary education',
 'Graduaat (HBO5)': 'College',
 'Hoger secundair, HBO5 verpleegkunde': 'College',
 'attest BUSO': 'Secondary education',
 'SNIT EN NAAD': 'Secondary education',
 'Bachelor,  korte type ': 'College',
 'Post-Graduaat': 'College',
 'GPB: lerarenopleiding ': 'College'
}

def c(row):
    main = row['Q1.Q18.[Wat is het hoogste diploma dat je behaalde? - Selected Choice]']
    other = row['Q1.Q18_9_TEXT.[Wat is het hoogste diploma dat je behaalde? - Andere - Tekst]']

    return map_main.get(main, map_other.get(other, None))

#edef

QC['General.Highest.Education'] = Qraw.apply(c, axis=1)

# %% [markdown]
# ## Health

# %% [markdown]
# ### BMI

# %%
#BMI

QC['Health.BMI'] = QC['General.Weight']/((QC['General.Height']/100)**2)

# %% [markdown]
# ### General health

# %%
freq(Qraw['Q1.Q34.[Hoe beoordeel je je algemene\ngezondheidstoestand?]'])
# Out:
# {None: 1325,
#  'Goed': 2811,
#  'Redelijk': 638,
#  'Zeer goed': 1171,
#  'Slecht': 60,
#  'Zeer slecht': 1,
#  '': 1}

# %%
#Binary variable
def clean_generalhealth(val):
    if pd.isna(val) or val == '':
        return None
    else :
        return val in ['Goed', 'Zeer goed']
    #fi
#edef


QC['Health.General.Q1.Good'] = Qraw['Q1.Q34.[Hoe beoordeel je je algemene\ngezondheidstoestand?]'].apply(clean_generalhealth)

# %%
#Dummy variables

##Zeer goed
def clean_generalhealth_zeergoed(val):
    if pd.isna(val) or val == '':
        return None
    else :
        return val == 'Zeer goed'
    #fi
#edef
QC['Health.General.Q1.VeryGood'] = Qraw['Q1.Q34.[Hoe beoordeel je je algemene\ngezondheidstoestand?]'].apply(clean_generalhealth_zeergoed)

##Goed
def clean_generalhealth_goed(val):
    if pd.isna(val) or val == '':
        return None
    else :
        return val == 'Goed'
    #fi
#edef
QC['Health.General.Q1.Good'] = Qraw['Q1.Q34.[Hoe beoordeel je je algemene\ngezondheidstoestand?]'].apply(clean_generalhealth_goed)

##Redelijk
def clean_generalhealth_redelijk(val):
    if pd.isna(val) or val == '':
        return None
    else :
        return val == 'Redelijk'
    #fi
#edef
QC['Health.General.Q1.Acceptable'] = Qraw['Q1.Q34.[Hoe beoordeel je je algemene\ngezondheidstoestand?]'].apply(clean_generalhealth_redelijk)

##Slecht/zeer slecht
def clean_generalhealth_slecht(val):
    if pd.isna(val) or val == '':
        return None
    else :
        return val == 'Slecht' or val == 'Zeer slecht'
    #fi
#edef
QC['Health.General.Q1.Bad'] = Qraw['Q1.Q34.[Hoe beoordeel je je algemene\ngezondheidstoestand?]'].apply(clean_generalhealth_slecht)

# %% [markdown]
# ### Excessive sweating

# %%
def clean_sweating(val):
    if pd.isna(val) or val == '':
        return None
    else :
        return val == 'Ja'
    #fi
#edef

QC['Health.Sweating.Excessive'] = Qraw['Q1.Q68.[Heb jij last van overmatig zweten?]'].apply(clean_sweating)

# %% [markdown]
# ### Medication

# %%
possible_meds = {
    "Birthcontrol pill" : ["Anticonceptie", "Anticonceptiepil"],
    "ibuprofen" : ['ibbuprofen', "Ibuprofen", "Neurofen"],
    "HRT" : ['Oestradiol gel', 'Oestrogel', 'oestrogel', 'Progebel', 'Progynova']
}

def flatten(lst, dropna=False):
    return [ v for l in lst for v in l if not (dropna & pd.isna(v)) ]
#edef

rel_cols = [ c for c in Qraw.columns if ('Q1.Q42' in c) and ('Naam' in c) ]

sorted(list(freq([ v.strip() for v in flatten(Qraw[rel_cols].values, True) if v != '']).items()), key=lambda x:x[0])

def _clean_meds(row, values):
    row_values = set([ v.strip() for v in row[rel_cols] if not pd.isna(v) ])

    return len(row_values & values) > 0
#edef

for med in possible_meds:
    QC["Health.medication.%s" % med] = Qraw[rel_cols].apply(lambda row:_clean_meds(row, set(possible_meds["HRT"])), axis = 1)
#efor

# %% [markdown]
# ## Sexual

# %% [markdown]
# ### Intercourse 3 months

# %%
# Penis
QC['Sexual.Penetration.Penis.3months'] = Qraw['Q1.Q47.2_4.[Welke seksuele handelingen heb je ontvangen in de afgelopen drie maanden? (meerdere antwoorden mogelijk) - Selected Choice - Vaginale penetratie met penis]'].apply(
    lambda x: None if pd.isna(x) else x not in [''])
# Fingers
QC['Sexual.Penetration.Fingers.3months'] = Qraw['Q1.Q47.2_3.[Welke seksuele handelingen heb je ontvangen in de afgelopen drie maanden? (meerdere antwoorden mogelijk) - Selected Choice - Vaginale penetratie met vingers]'].apply(
    lambda x: None if pd.isna(x) else x not in [''])
# Toy
QC['Sexual.Penetration.Toy.3months'] = Qraw['Q1.Q47.2_5.[Welke seksuele handelingen heb je ontvangen in de afgelopen drie maanden? (meerdere antwoorden mogelijk) - Selected Choice - Vaginale penetratie met speeltjes]'].apply(
    lambda x: None if pd.isna(x) else x not in [''])
# Other
QC['Sexual.Penetration.Other.3months'] = Qraw['Q1.Q47.2_6.[Welke seksuele handelingen heb je ontvangen in de afgelopen drie maanden? (meerdere antwoorden mogelijk) - Selected Choice - Vaginale penetratie met andere:]'].apply(
    lambda x: None if pd.isna(x) else x not in [''])

# Penetration general
QC['Sexual.Penetration.3months'] = QC.apply(
    lambda x: None if any(pd.isna(x[['Sexual.Penetration.Penis.3months','Sexual.Penetration.Fingers.3months', 'Sexual.Penetration.Toy.3months', 'Sexual.Penetration.Other.3months']])) else not(x['Sexual.Penetration.Penis.3months'] or x['Sexual.Penetration.Fingers.3months'] or x['Sexual.Penetration.Toy.3months'] or x['Sexual.Penetration.Other.3months']), axis=1)

# %% [markdown]
# ### Intercourse 24h

# %%
# Penis
QC['Sexual.Penetration.Penis.24h'] = Qraw['Q2.Q23_4.[Heb je de afgelopen 24 uur de volgende seksuele handelingen ontvangen of bij jezelf uitgevoerd (masturbatie)? (Meerdere antwoorden mogelijk) - Selected Choice - Vaginale penetratie met penis]'].apply(
    lambda x: None if pd.isna(x) else x not in [''])
# Fingers
QC['Sexual.Penetration.Fingers.24h'] = Qraw['Q2.Q23_3.[Heb je de afgelopen 24 uur de volgende seksuele handelingen ontvangen of bij jezelf uitgevoerd (masturbatie)? (Meerdere antwoorden mogelijk) - Selected Choice - Vaginale penetratie met vingers]'].apply(
    lambda x: None if pd.isna(x) else x not in [''])
# Toy
QC['Sexual.Penetration.Toy.24h'] = Qraw['Q2.Q23_5.[Heb je de afgelopen 24 uur de volgende seksuele handelingen ontvangen of bij jezelf uitgevoerd (masturbatie)? (Meerdere antwoorden mogelijk) - Selected Choice - Vaginale penetratie met speeltjes]'].apply(
    lambda x: None if pd.isna(x) else x not in [''])
# Other had one real answer, rest were none or swab so left it out

# Penetration general
QC['Sexual.Penetration.24h'] = QC.apply(
    lambda x: None if any(pd.isna(x[['Sexual.Penetration.Penis.24h','Sexual.Penetration.Fingers.24h', 'Sexual.Penetration.Toy.24h']])) else not(x['Sexual.Penetration.Penis.24h'] or x['Sexual.Penetration.Fingers.24h'] or x['Sexual.Penetration.Toy.24h']), axis=1)

# %% [markdown]
# ## Reproductive

# %% [markdown]
# ### Menstrual cycle

# %%
def determine_phases(row):
    """
    returns
     string
    """
    cycle_disrupted = row['Q1.Q52.3.[Hoeveel dagen zijn er gemiddeld tussen de eerste dag van je menstruatie\nen de eerste dag van je volgende? Je hoeft enkel het aantal dagen in te vullen indien je geen hormonale anticonceptie gebruikt die je cyclus kan beïnvloeden. - Selected Choice]'] == "Ik gebruik hormonale anticonceptie of een andere hormonale behandeling die mijn menstruele cyclus kan beïnvloeden"
    cycle_days     = row['Q1.Q52.3_4_TEXT.[Hoeveel dagen zijn er gemiddeld tussen de eerste dag van je menstruatie\nen de eerste dag van je volgende? Je hoeft enkel het aantal dagen in te vullen indien je geen hormonale anticonceptie gebruikt die je cyclus kan beïnvloeden. - Ik gebruik geen hormonale anticonceptie of een andere hormonale behandeling die mijn menstruele cyclus kan beïnvloeden - Tekst]']
    current_day    = row['A.day_of_cycle']
    
    if cycle_disrupted:
        return 'not_applicable'
    #fi
    
    if isinstance(cycle_days, str):
        return "unknown"
    #fi
    
    if pd.isna(cycle_days):
        cycle_days = 28
    #fi
    if pd.isna(current_day):
        return 'unknown'
    #fi
    
    if (cycle_days < 21) or (cycle_days > 35):
        return 'unknown'
    #fi
    
    if cycle_days <= 24:
        ovulation = cycle_days - 12
    elif cycle_days <= 31:
        ovulation = cycle_days - 14
    else:
        ovulation = cycle_days - 16
    #fi
    
    if current_day <= (ovulation-6):
        return 'Follicular'
    elif current_day <= (ovulation+2):
        return 'Ovulation'
    else:
        return 'Luteal'
    #fi
    
    return 'unknown'
#edef

phase = Qraw.apply(determine_phases, axis=1)



col_values = ['Luteal', 'Ovulation', 'Follicular']
for cv in col_values:
    QC['Reproductive.Cycle.Phase.%s' % cv] = phase.apply(lambda x: True if x == cv else None if x not in col_values else False)
#efor

# %% [markdown]
# ### Perimenopause

# %%
QC['Reproductive.PeriMenopause'] = Qraw['Q1.Q52.2.[Heeft dit te maken met één van de onderstaande mogelijkheden? - Selected Choice]'].apply(lambda x: str(x).lower() in ['c','d'])

# %% [markdown]
# ### Miscarriages, abortion, pretermbirth

# %%
_rel = Qraw[[c for c in Qraw if 'uitgedragen' in c]]

for rtype, rvalues in {'Miscarriage': ['Nee afgebroken, miskraam met medicatie', 'Nee afgebroken, spontane miskraam', 'Nee afgebroken, curettage miskraam'],
                      'PretermBirth': ['Nee, vroeggeboorte'],
                      'Abortion': ['Nee afgebroken, abortus']}.items():
    QC['Reproductive.Pregnancy.%s' % rtype] = _rel.applymap(lambda x: x in rvalues).any(axis=1)
#efor
# Out:
# C:\Users\LUCP12511\AppData\Local\Temp\ipykernel_20312\1108683355.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   QC['Reproductive.Pregnancy.%s' % rtype] = _rel.applymap(lambda x: x in rvalues).any(axis=1)
# C:\Users\LUCP12511\AppData\Local\Temp\ipykernel_20312\1108683355.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   QC['Reproductive.Pregnancy.%s' % rtype] = _rel.applymap(lambda x: x in rvalues).any(axis=1)
# C:\Users\LUCP12511\AppData\Local\Temp\ipykernel_20312\1108683355.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   QC['Reproductive.Pregnancy.%s' % rtype] = _rel.applymap(lambda x: x in rvalues).any(axis=1)

# %% [markdown]
# ### Pregnancy attempted

# %%
QC['Reproductive.Pregnancy.Attempted'] = Qraw['Q1.Q49.[Heb je ooit actief geprobeerd om zwanger te worden?]'].apply(
    lambda x: None if pd.isna(x) else x == 'Ja')

# %% [markdown]
# ### Breastfeeding

# %%
QC['Reproductive.Breastfeeding'] = Qraw['Q2.Q24.[Geef je op dit moment borstvoeding?]'].apply(
    lambda x: None if pd.isna(x) else x == 'Ja')

# %% [markdown]
# ### Number of biological children

# %%
def clean_nchildbio(val):
    if pd.isna(val):
        return None
    elif val == '':
        return 0
    elif str(val).isnumeric():
        return int(val)
    else:
        return None
    #fi
#edef

QC['Reproductive.Children.n.biological'] = Qraw["Q1.Q6_1_TEXT.[Heb je kinderen? (Meerdere antwoorden mogelijk) - Biologische kinderen: hoeveel? - Tekst]"].apply(clean_nchildbio)

# %% [markdown]
# ### Number of pregnancies

# %%
def clean_npreg(val):
    if pd.isna(val):
        return None
    elif str(val).isnumeric():
        return int(val)
    else:
        return None
    #fi
#edef

QC['Reproductive.Pregnancy.n'] = Qraw["Q1.Q50.[Hoeveel keer was je al zwanger?]"].apply(clean_npreg)

# %% [markdown]
# ### Early menopause

# %%
def clean_earlymenopause(val):
    if pd.isna(val):
        return None
    else:
        return 'menopauze' in val
    #fi
#edef

QC['Reproductive.PeriMenopause.Early'] = Qraw['Q1.Q37_9_TEXT.[Heb je één van onderstaande aandoeningen? (Graag de aandoening\nvermelden) (meerdere antwoorden mogelijk) - Voortplantingsstelsel, vb. endometriose - Tekst]'].apply(clean_earlymenopause)

# %% [markdown]
# ### Date and time since last menstruation

# %%
import datetime

# Date of sample: 'A.Sample date'

def clean_datelastcycle (row):
    if pd.isna(row):
        return None
    elif 'De eerste dag van' in row['Q2.Q28.[Wanneer was de eerste dag van je laatste menstruatie? - Selected Choice]']:
        return date = row["Q2.Q28_7_TEXT.[Wanneer was de eerste dag van je laatste menstruatie? - De eerste dag van mijn laatste menstruatie was (dd/mm/jjjj): - tekst]"]        
    else:
        return None
    #fi
#edef
    
QC['Reproductive.Date.Last.Menstruation'] = Qraw.apply(clean_datelastcycle, axis=1)
# Out:
#   Cell In[111], line 9
#     return date = row["Q2.Q28_7_TEXT.[Wanneer was de eerste dag van je laatste menstruatie? - De eerste dag van mijn laatste menstruatie was (dd/mm/jjjj): - tekst]"]
#                 ^
# SyntaxError: invalid syntax

# %%
def c(row):
    main = row['Q1.Q18.[Wat is het hoogste diploma dat je behaalde? - Selected Choice]']
    other = row['Q1.Q18_9_TEXT.[Wat is het hoogste diploma dat je behaalde? - Andere - Tekst]']

    return map_main.get(main, map_other.get(other, None))

#edef

QC['General.Highest.Education'] = Qraw.apply(c, axis=1)

date = datetime.datetime.strptime("07/09/2024", "%d/%m/%Y")
(date - date).days

# %%
freq(Qraw['Q2.Q28_7_TEXT.[Wanneer was de eerste dag van je laatste menstruatie? - De eerste dag van mijn laatste menstruatie was (dd/mm/jjjj): - tekst]'])

probeersle = 'De eerste dag van'
tekst = "De eerste dag van mijn laatste menstruatie was (dd/mm/jjjj):"

probeersle in tekst
# Out:
# True

# %% [markdown]
# ### Hormonal contraception

# %%
freq(Qraw['Q1.Q51_2.[Welke middelden heb je in de afgelopen drie maanden gebruikt om niet\nzwanger te worden? Gelieve ook het merk te geven. (Meerdere antwoorden mogelijk) - Selected Choice - Minipil:]'])
freq(Qraw['Q1.Q51.1.[Gebruik je op dit moment een andere methode of merk? - Selected Choice]'])
# Out:
# {None: 1325,
#  'Nee, ik gebruik nog steeds dezelfde methode': 3221,
#  'Hormoonspiraal (bv. Mirena):': 94,
#  'Ik gebruik geen anticonceptie meer': 219,
#  '': 917,
#  'Anticonceptiepil:': 73,
#  'Minipil:': 11,
#  'Condoom:': 64,
#  'Coitus interruptus (= penis terugtrekken voor zaadlozing)': 10,
#  'Anticonceptiering (bv. Nuvaring):': 24,
#  'Andere:': 27,
#  'Periodieke onthouding (= niet vrijen in vruchtbare periode)': 6,
#  'Koperspiraal:': 10,
#  'Anticonceptiepleister (bv. Evra):': 2,
#  'Prikpil:': 3,
#  'Hormonaal implantaat (bv. Implanon):': 1}

# %% [markdown]
# ## Life style

# %%
## rel_cols = [ c for c in Qraw.columns if 'Q1.Q37_9' in c]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[243], line 2
#       1 ## rel_cols = [ c for c in Qraw.columns if 'Q1.Q37_9' in c]
# ----> 2 row_values
#
# NameError: name 'row_values' is not defined

# %% [markdown]
# ### Partner

# %%
col = 'Q1.Q4.[Mijn partner(s) is/zijn...]'
freq(Qraw[col])
col_values = {'Man' : 'Man', 'Vrouw' : 'Woman'}
for cv in col_values:
    QC['Lifestyle.Partner.Is%s' % col_values[cv]] = Qraw[col].apply(lambda x: True if x == cv else None if x not in col_values else False)
    print('Lifestyle.Partner.Is%s' % col_values[cv])
#efor

QC['Lifestyle.Partner.OneVsSingle'] = Qraw['Q1.Q47.[Heb je de afgelopen drie maanden één of meerdere seksuele\npartner(s) gehad? - Selected Choice]'].apply(
    lambda x: None if (pd.isna(x) or x in ['Ja, meerdere vaste partners: hoeveel?', 'Ja, wisselende partners: hoeveel?']) else x == 'Ja, één vaste partner')
QC['Lifestyle.Partner.OneVsMany'] = Qraw['Q1.Q47.[Heb je de afgelopen drie maanden één of meerdere seksuele\npartner(s) gehad? - Selected Choice]'].apply(
    lambda x: None if (pd.isna(x) or x in ['Nee']) else x != 'Ja, één vaste partner')
# Out:
# Lifestyle.Partner.IsMan
# Lifestyle.Partner.IsWoman

# %% [markdown]
# ### Current smoker

# %%
QC['Lifestyle.Drugs.Current_smoker'] = Qraw['Q1.Q21.[Rook je? Geef ook op hoeveel sigaretten je per dag rook(te) - Selected Choice]'].apply(
    lambda x: None if pd.isna(x) else x == 'Ja')

# %% [markdown]
# ### Current druguser

# %%
QC['Lifestyle.Drugs.Current_druguser'] = Qraw['Q1.Q22.[Gebruik je drugs (exclusief alcohol)? Gelieve ook aan te geven welke. Deze informatie wordt pseudoniem verwerkt. Wij hebben het grootste respect voor jou en voor je privacy. - Selected Choice]'].apply(
    lambda x: None if pd.isna(x) else x == 'Ja')

# %% [markdown]
# ### Current alcohol yes/no

# %%
def current_alcohol(val):
    if pd.isna(val):
        return None
    else:
        return val != 'Ik drink geen alcohol'
    #fi
#edef

QC['Lifestyle.Drugs.Current_alcohol'] = Qraw['Q1.Q30_4.[Als je alcohol drinkt, wat drink je dan meestal? (meerdere antwoorden mogelijk) - Selected Choice - Ik drink geen alcohol]'].apply(current_alcohol)

# %% [markdown]
# ### Stress

# %%
#Binary variable
def clean_stress(val):
    if pd.isna(val) or val == '':
        return None
    else :
        return val in ['Vaak', 'Meestal', 'Voortdurend']
    #fi
#edef


QC['Lifestyle.Mood.Stress.4weeks'] = Qraw['Q1.Q46_6.[Hoe voelde je je de afgelopen vier weken? - Voelde je je gestresseerd?]'].apply(clean_stress)

#Dummy variables

##Voortdurend
def clean_stress_voortdurend(val):
    if pd.isna(val) or val == '':
        return None
    else :
        return val == 'Voortdurend'
    #fi
#edef
QC['Lifestyle.Mood.Stress.4weeks.Constantly'] = Qraw['Q1.Q46_6.[Hoe voelde je je de afgelopen vier weken? - Voelde je je gestresseerd?]'].apply(clean_stress_voortdurend)

##Meestal
def clean_stress_meestal(val):
    if pd.isna(val) or val == '':
        return None
    else :
        return val == 'Meestal'
    #fi
#edef
QC['Lifestyle.Mood.Stress.4weeks.Usually'] = Qraw['Q1.Q46_6.[Hoe voelde je je de afgelopen vier weken? - Voelde je je gestresseerd?]'].apply(clean_stress_meestal)

##Vaak
def clean_stress_vaak(val):
    if pd.isna(val) or val == '':
        return None
    else :
        return val == 'Vaak'
    #fi
#edef
QC['Lifestyle.Mood.Stress.4weeks.Often'] = Qraw['Q1.Q46_6.[Hoe voelde je je de afgelopen vier weken? - Voelde je je gestresseerd?]'].apply(clean_stress_vaak)

##Soms
def clean_stress_soms(val):
    if pd.isna(val) or val == '':
        return None
    else :
        return val == 'Soms'
    #fi
#edef
QC['Lifestyle.Mood.Stress.4weeks.Sometimes'] = Qraw['Q1.Q46_6.[Hoe voelde je je de afgelopen vier weken? - Voelde je je gestresseerd?]'].apply(clean_stress_soms)

##Zelden
def clean_stress_zelden(val):
    if pd.isna(val) or val == '':
        return None
    else :
        return val == 'Zelden'
    #fi
#edef
QC['Lifestyle.Mood.Stress.4weeks.Rarely'] = Qraw['Q1.Q46_6.[Hoe voelde je je de afgelopen vier weken? - Voelde je je gestresseerd?]'].apply(clean_stress_zelden)

##Nooit
def clean_stress_nooit(val):
    if pd.isna(val) or val == '':
        return None
    else :
        return val == 'Nooit'
    #fi
#edef
QC['Lifestyle.Mood.Stress.4weeks.Never'] = Qraw['Q1.Q46_6.[Hoe voelde je je de afgelopen vier weken? - Voelde je je gestresseerd?]'].apply(clean_stress_nooit)

# %% [markdown]
# ### Increased stress

# %%
freq(Qraw['Q2.Q20.[Voelde je je de afgelopen maand gemiddeld somberder en/of meer gestresseerd dan normaal?]'])
# Out:
# {None: 2753,
#  'Hetzelfde': 1965,
#  'Ja': 955,
#  'Minder dan eerder aangegeven': 283,
#  '': 51}

# %%
def clean_increasedstress(val):
    if pd.isna(val) or val == '':
        return None
    else :
        return val == 'Ja'
    #fi
#edef


QC['Lifestyle.Mood.Stress.Increased'] = Qraw['Q2.Q20.[Voelde je je de afgelopen maand gemiddeld somberder en/of meer gestresseerd dan normaal?]'].apply(clean_increasedstress)

# %% [markdown]
# ## Environment

# %% [markdown]
# ### Diet

# %%
QC['Nutrition.EatsMeat'] = Qraw['Q1.Q29_4.[Hoe regelmatig heb je de onderstaande zaken gegeten of gedronken in de afgelopen 3 maanden? - Vlees]'].apply(
    lambda x: None if pd.isna(x) else x not in ['Zelden', 'Nooit'])

QC['Nutrition.EatsFish'] = Qraw['Q1.Q29_6.[Hoe regelmatig heb je de onderstaande zaken gegeten of gedronken in de afgelopen 3 maanden? - Vis]'].apply(
    lambda x: None if pd.isna(x) else x in ['Zelden', 'Nooit'])

QC['Nutrition.EatsAnimals'] = Qraw['Q1.Q29_5.[Hoe regelmatig heb je de onderstaande zaken gegeten of gedronken in de afgelopen 3 maanden? - Dierlijke producten (eieren, kaas, gelatine,...)]'].apply(
    lambda x: None if pd.isna(x) else x in ['Zelden', 'Nooit'])

QC['Nutrition.Vegetarian'] = QC.apply(
    lambda x: None if any(pd.isna(x[['Nutrition.EatsMeat','Nutrition.EatsFish']])) else not(x['Nutrition.EatsFish'] or x['Nutrition.EatsMeat']), axis=1)

QC['Nutrition.Pescetarian'] = QC.apply(
    lambda x: None if any(pd.isna(x[['Nutrition.EatsMeat','Nutrition.EatsFish']])) else x['Nutrition.EatsFish'] and not(x['Nutrition.EatsMeat']), axis=1)

QC['Nutrition.Vegan'] = QC.apply(
    lambda x: None if any(pd.isna(x[['Nutrition.EatsMeat','Nutrition.EatsFish', 'Nutrition.EatsAnimals']])) else not(x['Nutrition.EatsFish'] or x['Nutrition.EatsMeat'] or x['Nutrition.EatsAnimals']), axis=1)

# %% [markdown]
# ### Living environment

# %%
QC['Environment.Urban'] = Qraw['Q1.Q15.[Hoe zou je het gebied waar je nu woont omschrijven?]'].apply(
    lambda x: None if pd.isna(x) else x in ['Stadskern', 'Dorpskern', 'Residentiële woonwijk', 'Drukke baan', 'Industriezone'])

QC['Environment.Coutryside'] = Qraw['Q1.Q15.[Hoe zou je het gebied waar je nu woont omschrijven?]'].apply(
    lambda x: None if pd.isna(x) else x in ['Groene zone/ recreatiegebied/...', 'Landelijk gebied'])

# %% [markdown]
# ### Belgium first three years of life

# %%
def is_belgium(v):
    if pd.isna(v):
        return None
    #fi
    v = v.lower()
    if 'belg' in v:
        return True
    elif v in ['be', 'antwerpen', 'neen', '0', 'geen', 'b', 'beglie' ]:
        return True
    else:
        return False
    #fi
#edef

QC['Environment.Belgium.First3Years'] = Qraw['Q1.Q9.[In welk(e) land(en) heb je gewoond tot en met je derde levensjaar? Indien dit enkel België is, mag je het ook opgeven.]'].apply(
    lambda x: is_belgium(x))

# %% [markdown]
# ### Economic

# %%
QC['Environment.Economic.HouseholdContribution'] = Qraw['Q2.Q7.[Hoe groot is je aandeel aan het gezinsinkomen?]'].apply(
    lambda x: None if pd.isna(x) else {'Ik heb het grootste aandeel ': 3/4,
 'Ik draag als enige bij ': 4/4,
 'We dragen evenveel bij  ': 2/4,
 'Ik draag het minste bij  ': 1/4,
 'Ik draag niet bij  ': 0/4}.get(x, None))

QC['Environment.Economic.FinancialDifficulties'] = Qraw['Q2.Q4.[Kan je maandelijks rondkomen met de som van totaal beschikbaar gezinsinkomen (alles inbegrepen*)? \n\n\n\n* De leefomstandigheden van een huishouden hangen natuurlijk in belangrijke mate af van het inkomen. Het gaat hier over het totale beschikbare inkomen van de verschillende leden van het huishouden samen. Meerdere leden kunnen dus bijdragen. Het totale beschikbare inkomen van een huishouden bestaat uit, (1) netto-lonen, wedden en nettobedrijfsinkomens voor zelfstandigen, (2) sociale uitkeringen en kinderbijslagen, (3) bijkomende inkomens zoals huuropbrengsten, intresten e.a. De som van al deze inkomens voor alle personen uit je huishouden is het totale beschikbare inkomen van je huishouden.]'].apply(
    lambda x: None if pd.isna(x) else (x in ['Eerder moeilijk', 'Moeilijk', 'Zeer moeilijk']))

# %% [markdown]
# # Export cleaned questionnaire

# %%
with RDM('../data/cleaned/IsalaFlow1.CleanedQuestionnaires.xlsx', 'w', nouser=True) as ofd:
    QC.to_excel(ofd)
#ewith

with RDM('../data/cleaned/IsalaFlow1.CleanedQuestionnaires.xlsx', 'w', nouser=True) as ofd:
    QC.to_pickle(ofd)
#ewith
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[114], line 1
# ----> 1 with RDM('../data/cleaned/IsalaFlow1.CleanedQuestionnaires.xlsx', 'w', nouser=True) as ofd:
#       2     QC.to_excel(ofd)
#       3 #ewith
#
# NameError: name 'RDM' is not defined

# %%
QC
# Out:
#                IsalaID General.Gender  General.Age  General.Height  \
# idx
# ISALA00006  ISALA00006           None          NaN             NaN
# ISALA00038  ISALA00038           None          NaN             NaN
# ISALA00039  ISALA00039          Vrouw         32.0           178.0
# ISALA00040  ISALA00040          Vrouw         24.0           168.0
# ISALA00041  ISALA00041           None          NaN             NaN
# ...                ...            ...          ...             ...
# ISALA06046  ISALA06046          Vrouw         32.0           173.0
# ISALA06047  ISALA06047          Vrouw         57.0           184.0
# ISALA06048  ISALA06048           None          NaN             NaN
# ISALA06049  ISALA06049          Vrouw         23.0           171.0
# ISALA06050  ISALA06050          Vrouw         25.0           171.0
#
#             General.Weight General.Highest.Education  Health.BMI  \
# idx
# ISALA00006             NaN                      None         NaN
# ISALA00038             NaN                      None         NaN
# ISALA00039            64.0                       PhD   20.199470
# ISALA00040            60.0                   College   21.258503
# ISALA00041             NaN                      None         NaN
# ...                    ...                       ...         ...
# ISALA06046            74.0                University   24.725183
# ISALA06047            57.0                University   16.836011
# ISALA06048             NaN                      None         NaN
# ISALA06049            64.0                University   21.887076
# ISALA06050            58.0                University   19.835163
#
#            Health.General.Q1.Good Health.General.Q1.VeryGood  \
# idx
# ISALA00006                   None                       None
# ISALA00038                   None                       None
# ISALA00039                   True                      False
# ISALA00040                   True                      False
# ISALA00041                   None                       None
# ...                           ...                        ...
# ISALA06046                   True                      False
# ISALA06047                  False                       True
# ISALA06048                   None                       None
# ISALA06049                   True                      False
# ISALA06050                   True                      False
#
#            Health.General.Q1.Acceptable  ... Sexual.Penetration.Toy.3months  \
# idx                                      ...
# ISALA00006                         None  ...                           None
# ISALA00038                         None  ...                           None
# ISALA00039                        False  ...                          False
# ISALA00040                        False  ...                          False
# ISALA00041                         None  ...                           None
# ...                                 ...  ...                            ...
# ISALA06046                        False  ...                          False
# ISALA06047                        False  ...                          False
# ISALA06048                         None  ...                           None
# ISALA06049                        False  ...                           True
# ISALA06050                        False  ...                          False
#
#            Sexual.Penetration.Other.3months  Sexual.Penetration.3months  \
# idx
# ISALA00006                             None                        None
# ISALA00038                             None                        None
# ISALA00039                            False                       False
# ISALA00040                            False                       False
# ISALA00041                             None                        None
# ...                                     ...                         ...
# ISALA06046                            False                       False
# ISALA06047                            False                        True
# ISALA06048                             None                        None
# ISALA06049                            False                       False
# ISALA06050                            False                       False
#
#            Sexual.Penetration.Penis.24h Sexual.Penetration.Fingers.24h  \
# idx
# ISALA00006                         None                           None
# ISALA00038                         None                           None
# ISALA00039                        False                          False
# ISALA00040                        False                          False
# ISALA00041                         None                           None
# ...                                 ...                            ...
# ISALA06046                         None                           None
# ISALA06047                         None                           None
# ISALA06048                         None                           None
# ISALA06049                        False                          False
# ISALA06050                         True                          False
#
#            Sexual.Penetration.Toy.24h Sexual.Penetration.24h  \
# idx
# ISALA00006                       None                   None
# ISALA00038                       None                   None
# ISALA00039                      False                   True
# ISALA00040                      False                   True
# ISALA00041                       None                   None
# ...                               ...                    ...
# ISALA06046                       None                   None
# ISALA06047                       None                   None
# ISALA06048                       None                   None
# ISALA06049                      False                   True
# ISALA06050                      False                  False
#
#            Health.medication.Birthcontrol pill Health.medication.ibuprofen  \
# idx
# ISALA00006                               False                       False
# ISALA00038                               False                       False
# ISALA00039                               False                       False
# ISALA00040                               False                       False
# ISALA00041                               False                       False
# ...                                        ...                         ...
# ISALA06046                               False                       False
# ISALA06047                               False                       False
# ISALA06048                               False                       False
# ISALA06049                               False                       False
# ISALA06050                               False                       False
#
#            Health.medication.HRT
# idx
# ISALA00006                 False
# ISALA00038                 False
# ISALA00039                 False
# ISALA00040                 False
# ISALA00041                 False
# ...                          ...
# ISALA06046                 False
# ISALA06047                 False
# ISALA06048                 False
# ISALA06049                 False
# ISALA06050                 False
#
# [6007 rows x 25 columns]

# %%
list(Qraw)
# Out:
# ['Q0.Status',
#  'Q0.Deelnemersnummer',
#  'Q0.Leeftijd',
#  'Q0.Woonde in België voor de eerste 3 levensjaren',
#  'Q0.Zwanger',
#  'Q0.Anticonceptiemethode',
#  'Q0.Postcode',
#  'Q1.StartDate.[Start Date]',
#  'Q1.EndDate.[End Date]',
#  'Q1.Status.[Response Type]',
#  'Q1.Progress',
#  'Q1.Duration (in seconds)',
#  'Q1.Finished',
#  'Q1.RecordedDate.[Recorded Date]',
#  'Q1.ResponseId.[Response ID]',
#  'Q1.ExternalReference.[External Data Reference]',
#  "Q1.IC4.[Ik heb het informatie- en toestemmingsformulier\ngelezen. Ik begrijp de voordelen en het belang van deze studie, maar ook de eventuele\nrisico's. Ik begrijp dat ik binnen het onderzoek een uitgebreide vragenlijst\nkrijg om te bepalen welke factoren een effect zouden kunnen hebben op het\nmicrobioom. Ik neem vrijwillig deel aan deze studie. Vandaag ([CurrentDate-d%2Fm%2FY])]",
#  'Q1.IC5.[Je kan alleen deelnemen aan Isala als je akkoord gaat met het toestemmingsformulier. Indien je hierover vragen hebt, kan je contact met ons opnemen via isala@uantwerpen.be. Om je antwoord aan te passen, kan je via het pijltje terugkeren naar de vorige vraag]',
#  'Q1.Q1.[Geslacht - Selected Choice]',
#  'Q1.Q1_5_TEXT.[Geslacht - Anders - Tekst]',
#  'Q1.Q1.1.[Sinds wanneer? (jaartal)]',
#  'Q1.Q2_1.[Enkele algemene vragen over jou: - Leeftijd (jaar)]',
#  'Q1.Q2_2.[Enkele algemene vragen over jou: - Lengte (cm)]',
#  'Q1.Q2_3.[Enkele algemene vragen over jou: - Gewicht (kg)]',
#  'Q1.Q3.[Zo beschrijf je best mijn huidige relatiestatus]',
#  'Q1.Q4.[Mijn partner(s) is/zijn...]',
#  'Q1.Q5.[Zo ziet mijn gezin er uit:]',
#  'Q1.Q5.1.[Hoe lang wonen jullie samen?]',
#  'Q1.Q5.2.[Met hoeveel mensen woon je samen in hetzelfde huis, jezelf er niet bijgerekend? (ook als het niet de hele tijd is)]',
#  'Q1.Q6_1.[Heb je kinderen? (Meerdere antwoorden mogelijk) - Selected Choice - Biologische kinderen: hoeveel?]',
#  'Q1.Q6_2.[Heb je kinderen? (Meerdere antwoorden mogelijk) - Selected Choice - Geadopteerde kinderen of pleegkinderen: hoeveel?]',
#  'Q1.Q6_3.[Heb je kinderen? (Meerdere antwoorden mogelijk) - Selected Choice - Pluskinderen (= stiefkinderen): hoeveel?]',
#  'Q1.Q6_4.[Heb je kinderen? (Meerdere antwoorden mogelijk) - Selected Choice - Geen kinderen]',
#  'Q1.Q6_1_TEXT.[Heb je kinderen? (Meerdere antwoorden mogelijk) - Biologische kinderen: hoeveel? - Tekst]',
#  'Q1.Q6_2_TEXT.[Heb je kinderen? (Meerdere antwoorden mogelijk) - Geadopteerde kinderen of pleegkinderen: hoeveel? - Tekst]',
#  'Q1.Q6_3_TEXT.[Heb je kinderen? (Meerdere antwoorden mogelijk) - Pluskinderen (= stiefkinderen): hoeveel? - Tekst]',
#  'Q1.Q6.1_1.[Hoe ben je bevallen? Begin met je eerste bevalling. - 1]',
#  'Q1.Q6.1_2.[Hoe ben je bevallen? Begin met je eerste bevalling. - 2]',
#  'Q1.Q6.1_3.[Hoe ben je bevallen? Begin met je eerste bevalling. - 3]',
#  'Q1.Q6.1_4.[Hoe ben je bevallen? Begin met je eerste bevalling. - 4]',
#  'Q1.Q6.1_5.[Hoe ben je bevallen? Begin met je eerste bevalling. - 5]',
#  'Q1.Q6.1_6.[Hoe ben je bevallen? Begin met je eerste bevalling. - 6]',
#  'Q1.Q6.1_7.[Hoe ben je bevallen? Begin met je eerste bevalling. - 7]',
#  'Q1.Q6.1_8.[Hoe ben je bevallen? Begin met je eerste bevalling. - 8]',
#  'Q1.Q6.1_9.[Hoe ben je bevallen? Begin met je eerste bevalling. - 9]',
#  'Q1.Q6.1_10.[Hoe ben je bevallen? Begin met je eerste bevalling. - 10]',
#  'Q1.Q6.1_11.[Hoe ben je bevallen? Begin met je eerste bevalling. - 11]',
#  'Q1.Q6.1_12.[Hoe ben je bevallen? Begin met je eerste bevalling. - 12]',
#  'Q1.Q6.1_13.[Hoe ben je bevallen? Begin met je eerste bevalling. - 13]',
#  'Q1.Q6.1_14.[Hoe ben je bevallen? Begin met je eerste bevalling. - 14]',
#  'Q1.Q6.1_15.[Hoe ben je bevallen? Begin met je eerste bevalling. - 15]',
#  'Q1.Q7.[Geef je op dit moment borstvoeding?]',
#  'Q1.Q8.[Ben je geboren in België?]',
#  'Q1.Q8.1_1.[Indien je niet bent geboren in België: - In welk land ben je geboren?]',
#  'Q1.Q8.1_2.[Indien je niet bent geboren in België: - Hoe oud was je toen je naar België kwam?]',
#  'Q1.Q9.[In welk(e) land(en) heb je gewoond tot en met je derde levensjaar? Indien dit enkel België is, mag je het ook opgeven.]',
#  'Q1.Q10.[Woon je permanent (of voor een periode langer dan 6 maanden) in België?]',
#  'Q1.Q11_4.[Welke nationaliteit(en) heeft je biologische moeder? - Selected Choice - Belg]',
#  'Q1.Q11_5.[Welke nationaliteit(en) heeft je biologische moeder? - Selected Choice - Andere]',
#  'Q1.Q11_5_TEXT.[Welke nationaliteit(en) heeft je biologische moeder? - Andere - Tekst]',
#  'Q1.Q12_4.[Welke nationaliteit(en) heeft je biologische vader? - Selected Choice - Belg]',
#  'Q1.Q12_5.[Welke nationaliteit(en) heeft je biologische vader? - Selected Choice - Andere]',
#  'Q1.Q12_5_TEXT.[Welke nationaliteit(en) heeft je biologische vader? - Andere - Tekst]',
#  'Q1.Q13.[Zijn er andere culturen / landen\nwaarmee je je ook identificeert naast België? - Selected Choice]',
#  'Q1.Q13_1_TEXT.[Zijn er andere culturen / landen\nwaarmee je je ook identificeert naast België? - Ja, welke? - Tekst]',
#  'Q1.Q14.[Hoe zou je het gebied waar je bent opgegroeid omschrijven? Deze vraag gaat over de plaats waar je het grootste deel van je jeugd\ndoorbracht. Als je\ntwijfelt, kies je de plek waar je het eerst lang verbleef.]',
#  'Q1.Q15.[Hoe zou je het gebied waar je nu woont omschrijven?]',
#  'Q1.Q16.[Kom je dagelijks in een omgeving met…..]',
#  'Q1.Q17.[Was je de afgelopen drie maanden in\nhet buitenland (voor minstens drie opeenvolgende  dagen)? - Selected Choice]',
#  'Q1.Q17_1_TEXT.[Was je de afgelopen drie maanden in\nhet buitenland (voor minstens drie opeenvolgende  dagen)? - Ja, naar welk(e) land(en)? - Tekst]',
#  'Q1.Q18.[Wat is het hoogste diploma dat je behaalde? - Selected Choice]',
#  'Q1.Q18_9_TEXT.[Wat is het hoogste diploma dat je behaalde? - Andere - Tekst]',
#  'Q1.Q19_1.[Heb je contact met dieren tijdens je werk of thuis? (meerdere antwoorden mogelijk) - Ja, op het werk]',
#  'Q1.Q19_2.[Heb je contact met dieren tijdens je werk of thuis? (meerdere antwoorden mogelijk) - Ja, ik heb binnenhuis huisdieren]',
#  'Q1.Q19_3.[Heb je contact met dieren tijdens je werk of thuis? (meerdere antwoorden mogelijk) - Ja, ik heb buitenhuis huisdieren]',
#  'Q1.Q19_4.[Heb je contact met dieren tijdens je werk of thuis? (meerdere antwoorden mogelijk) - Nee]',
#  'Q1.Q19.1_1.[Indien je in contact komt met dieren, hoeveel en welke dieren? - Aantal dieren op het werk?]',
#  'Q1.Q19.1_2.[Indien je in contact komt met dieren, hoeveel en welke dieren? - Welke dieren op het werk?]',
#  'Q1.Q19.1_3.[Indien je in contact komt met dieren, hoeveel en welke dieren? - Aantal binnenhuis huisdieren?]',
#  'Q1.Q19.1_4.[Indien je in contact komt met dieren, hoeveel en welke dieren? - Welke binnenhuis huisdieren?]',
#  'Q1.Q19.1_5.[Indien je in contact komt met dieren, hoeveel en welke dieren? - Aantal buitenhuis huisdieren?]',
#  'Q1.Q19.1_6.[Indien je in contact komt met dieren, hoeveel en welke dieren? - Welke buitenhuis huisdieren?]',
#  'Q1.Q20_1.[Geef je werkritme aan. Als je verschillende jobs combineert, tel dan alles op (meerdere antwoorden mogelijk) - Selected Choice - Voltijds]',
#  'Q1.Q20_2.[Geef je werkritme aan. Als je verschillende jobs combineert, tel dan alles op (meerdere antwoorden mogelijk) - Selected Choice - Deeltijds (hoeveel procent?)]',
#  'Q1.Q20_3.[Geef je werkritme aan. Als je verschillende jobs combineert, tel dan alles op (meerdere antwoorden mogelijk) - Selected Choice - Langdurig ziekteverlof (meer dan drie maanden)]',
#  'Q1.Q20_4.[Geef je werkritme aan. Als je verschillende jobs combineert, tel dan alles op (meerdere antwoorden mogelijk) - Selected Choice - Werkloos]',
#  'Q1.Q20_5.[Geef je werkritme aan. Als je verschillende jobs combineert, tel dan alles op (meerdere antwoorden mogelijk) - Selected Choice - (Vervroegd) pensioen]',
#  'Q1.Q20_6.[Geef je werkritme aan. Als je verschillende jobs combineert, tel dan alles op (meerdere antwoorden mogelijk) - Selected Choice - Student]',
#  'Q1.Q20_7.[Geef je werkritme aan. Als je verschillende jobs combineert, tel dan alles op (meerdere antwoorden mogelijk) - Selected Choice - Vrijwilligerswerk]',
#  'Q1.Q20_8.[Geef je werkritme aan. Als je verschillende jobs combineert, tel dan alles op (meerdere antwoorden mogelijk) - Selected Choice - Andere:]',
#  'Q1.Q20_2_TEXT.[Geef je werkritme aan. Als je verschillende jobs combineert, tel dan alles op (meerdere antwoorden mogelijk) - Deeltijds (hoeveel procent?) - Tekst]',
#  'Q1.Q20_8_TEXT.[Geef je werkritme aan. Als je verschillende jobs combineert, tel dan alles op (meerdere antwoorden mogelijk) - Andere: - Tekst]',
#  'Q1.Q20.1.[In welke sector werk je? - Selected Choice]',
#  'Q1.Q20.1_24_TEXT.[In welke sector werk je? - Andere: - Tekst]',
#  'Q1.Q20.2_1.[Ik werk meestal (meerdere antwoorden mogelijk) - Selected Choice - overdag]',
#  "Q1.Q20.2_2.[Ik werk meestal (meerdere antwoorden mogelijk) - Selected Choice - 's nachts]",
#  'Q1.Q20.2_3.[Ik werk meestal (meerdere antwoorden mogelijk) - Selected Choice - In shiften]',
#  'Q1.Q20.2_4.[Ik werk meestal (meerdere antwoorden mogelijk) - Selected Choice - Andere:]',
#  'Q1.Q20.2_4_TEXT.[Ik werk meestal (meerdere antwoorden mogelijk) - Andere: - Tekst]',
#  'Q1.Q20.3_1.[Indien je in shiften werkt, welke shiften? (meerdere antwoorden mogelijk) - Selected Choice - Vroege]',
#  'Q1.Q20.3_2.[Indien je in shiften werkt, welke shiften? (meerdere antwoorden mogelijk) - Selected Choice - Late]',
#  'Q1.Q20.3_3.[Indien je in shiften werkt, welke shiften? (meerdere antwoorden mogelijk) - Selected Choice - Nacht]',
#  'Q1.Q20.3_4.[Indien je in shiften werkt, welke shiften? (meerdere antwoorden mogelijk) - Selected Choice - Andere]',
#  'Q1.Q20.3_4_TEXT.[Indien je in shiften werkt, welke shiften? (meerdere antwoorden mogelijk) - Andere - Tekst]',
#  'Q1.Q20.4_1.[Beschrijf je werksituatie onder normale omstandigheden: - Contact met andere mensen]',
#  'Q1.Q20.4_2.[Beschrijf je werksituatie onder normale omstandigheden: - Contact met chemische stoffen (bv.chloor, vlamvertragers, teflon, aceton, ontsmettingsmiddel, labomateriaal, ...)]',
#  'Q1.Q20.4_3.[Beschrijf je werksituatie onder normale omstandigheden: - Fysiek contact met buitenplanten]',
#  'Q1.Q20.4_4.[Beschrijf je werksituatie onder normale omstandigheden: - Fysiek contact met binnenplanten]',
#  'Q1.Q21.[Rook je? Geef ook op hoeveel sigaretten je per dag rook(te) - Selected Choice]',
#  'Q1.Q21_1_TEXT.[Rook je? Geef ook op hoeveel sigaretten je per dag rook(te) - Ja - Tekst]',
#  'Q1.Q21_2_TEXT.[Rook je? Geef ook op hoeveel sigaretten je per dag rook(te) - Nee, ex-roker - Tekst]',
#  'Q1.Q21.1.[Hoelang rook je al? Deze vraag gaat over de totale periode - Selected Choice]',
#  'Q1.Q21.1_1_TEXT.[Hoelang rook je al? Deze vraag gaat over de totale periode - Jaren - Tekst]',
#  'Q1.Q21.1_2_TEXT.[Hoelang rook je al? Deze vraag gaat over de totale periode - Maanden - Tekst]',
#  'Q1.Q21.2.[Hoelang heb je gerookt? Deze vraag gaat over de totale periode - Selected Choice]',
#  'Q1.Q21.2_1_TEXT.[Hoelang heb je gerookt? Deze vraag gaat over de totale periode - Jaren - Tekst]',
#  'Q1.Q21.2_2_TEXT.[Hoelang heb je gerookt? Deze vraag gaat over de totale periode - Maanden - Tekst]',
#  'Q1.Q21.3.[Sinds wanneer ben je gestopt met roken? Geef het jaartal op]',
#  'Q1.Q22.[Gebruik je drugs (exclusief alcohol)? Gelieve ook aan te geven welke. Deze informatie wordt pseudoniem verwerkt. Wij hebben het grootste respect voor jou en voor je privacy. - Selected Choice]',
#  'Q1.Q22_1_TEXT.[Gebruik je drugs (exclusief alcohol)? Gelieve ook aan te geven welke. Deze informatie wordt pseudoniem verwerkt. Wij hebben het grootste respect voor jou en voor je privacy. - Ja - Tekst]',
#  'Q1.Q22_2_TEXT.[Gebruik je drugs (exclusief alcohol)? Gelieve ook aan te geven welke. Deze informatie wordt pseudoniem verwerkt. Wij hebben het grootste respect voor jou en voor je privacy. - Nee, ex-drugsgebruiker - Tekst]',
#  'Q1.Q22.1.[Wat is de frequentie van je huidig druggebruik?]',
#  'Q1.Q22.2.[Hoelang gebruik je al drugs? Deze vraag gaat over de totale periode - Selected Choice]',
#  'Q1.Q22.2_1_TEXT.[Hoelang gebruik je al drugs? Deze vraag gaat over de totale periode - Jaren - Tekst]',
#  'Q1.Q22.2_2_TEXT.[Hoelang gebruik je al drugs? Deze vraag gaat over de totale periode - Maanden - Tekst]',
#  'Q1.Q22.3.[Wat was de frequentie van je toenmalig druggebruik? We vragen hier naar de laatste periode van jouw druggebruik.]',
#  'Q1.Q22.4.[Indien je vroeger drugs gebruikte, hoeveel jaren of maanden geleden was dit? - Selected Choice]',
#  'Q1.Q22.4_1_TEXT.[Indien je vroeger drugs gebruikte, hoeveel jaren of maanden geleden was dit? - Jaren - Tekst]',
#  'Q1.Q22.4_2_TEXT.[Indien je vroeger drugs gebruikte, hoeveel jaren of maanden geleden was dit? - Maanden - Tekst]',
#  'Q1.Q22.5.[Hoelang gebruikte je drugs? Deze vraag gaat over de totale periode. - Selected Choice]',
#  'Q1.Q22.5_1_TEXT.[Hoelang gebruikte je drugs? Deze vraag gaat over de totale periode. - Jaren - Tekst]',
#  'Q1.Q22.5_2_TEXT.[Hoelang gebruikte je drugs? Deze vraag gaat over de totale periode. - Maanden - Tekst]',
#  'Q1.Q25_1.[Hoeveel uur slaap je gemiddeld per nacht? - Op werkdagen]',
#  'Q1.Q25_2.[Hoeveel uur slaap je gemiddeld per nacht? - Op vrije dagen]',
#  'Q1.Q26_1.[Hoeveel uur per week sport je? (Meerdere antwoorden mogelijk) - Selected Choice - Ik doe geen sport]',
#  'Q1.Q26_2.[Hoeveel uur per week sport je? (Meerdere antwoorden mogelijk) - Selected Choice - Matige fysieke activiteit]',
#  'Q1.Q26_3.[Hoeveel uur per week sport je? (Meerdere antwoorden mogelijk) - Selected Choice - Intensieve fysieke activiteit]',
#  'Q1.Q26_2_TEXT.[Hoeveel uur per week sport je? (Meerdere antwoorden mogelijk) - Matige fysieke activiteit - Tekst]',
#  'Q1.Q26_3_TEXT.[Hoeveel uur per week sport je? (Meerdere antwoorden mogelijk) - Intensieve fysieke activiteit - Tekst]',
#  'Q1.Q26.1.[Welke sporten beoefen je?]',
#  'Q1.Q27_1.[Hoeveel minuten per dag spendeer je gemiddeld buiten? Denk aan de afgelopen 3 maanden - In de week]',
#  'Q1.Q27_2.[Hoeveel minuten per dag spendeer je gemiddeld buiten? Denk aan de afgelopen 3 maanden - In het weekend]',
#  'Q1.Q28_1.[Hoe vaak neem je probiotica of goede bacteriën in de vorm van onderstaande producten in? - In zuivelproducten zoals Yakult en Actimel]',
#  'Q1.Q28_2.[Hoe vaak neem je probiotica of goede bacteriën in de vorm van onderstaande producten in? - In yoghurt]',
#  'Q1.Q28_3.[Hoe vaak neem je probiotica of goede bacteriën in de vorm van onderstaande producten in? - Capsules zoals Enterol, Probactiol of andere vergelijkbare supplementen uit de apotheek of de drogisterij?]',
#  'Q1.Q28.1#1_1_1.[Hoe vaak neem je probiotica in in de vorm van onderstaande producten? - Q28.1#1 - In zuivelproducten zoals Yakult en Actimel - Welke producten?]',
#  'Q1.Q28.1#1_2_1.[Hoe vaak neem je probiotica in in de vorm van onderstaande producten? - Q28.1#1 - In yoghurt - Welke producten?]',
#  'Q1.Q28.1#1_3_1.[Hoe vaak neem je probiotica in in de vorm van onderstaande producten? - Q28.1#1 - Capsules zoals Enterol, Probactiol of andere vergelijkbare supplementen uit... - Capsules zoals Enterol, Probactiol of andere vergelijkbare supplementen uit de apotheek of de drogisterij? - Welke producten?]',
#  'Q1.Q28.1#2_1.[Hoe vaak neem je probiotica in in de vorm van onderstaande producten? - Heb je de afgelopen maand dergelijke producten gebruikt? - In zuivelproducten zoals Yakult en Actimel]',
#  'Q1.Q28.1#2_2.[Hoe vaak neem je probiotica in in de vorm van onderstaande producten? - Heb je de afgelopen maand dergelijke producten gebruikt? - In yoghurt]',
#  'Q1.Q28.1#2_3.[Hoe vaak neem je probiotica in in de vorm van onderstaande producten? - Heb je de afgelopen maand dergelijke producten gebruikt? - Capsules zoals Enterol, Probactiol of andere vergelijkbare supplementen uit de apotheek of de drogisterij?]',
#  'Q1.Q29_1.[Hoe regelmatig heb je de onderstaande zaken gegeten of gedronken in de afgelopen 3 maanden? - Zuivelproducten (kaas, melk, yoghurt, karnemelk,...)]',
#  'Q1.Q29_2.[Hoe regelmatig heb je de onderstaande zaken gegeten of gedronken in de afgelopen 3 maanden? - Gefermenteerde voeding (olijven, salami, zuurkool, zuurdesembrood, augurken, ...)]',
#  'Q1.Q29_3.[Hoe regelmatig heb je de onderstaande zaken gegeten of gedronken in de afgelopen 3 maanden? - Alcohol]',
#  'Q1.Q29_4.[Hoe regelmatig heb je de onderstaande zaken gegeten of gedronken in de afgelopen 3 maanden? - Vlees]',
#  'Q1.Q29_5.[Hoe regelmatig heb je de onderstaande zaken gegeten of gedronken in de afgelopen 3 maanden? - Dierlijke producten (eieren, kaas, gelatine,...)]',
#  'Q1.Q29_6.[Hoe regelmatig heb je de onderstaande zaken gegeten of gedronken in de afgelopen 3 maanden? - Vis]',
#  'Q1.Q29_7.[Hoe regelmatig heb je de onderstaande zaken gegeten of gedronken in de afgelopen 3 maanden? - Zoete dranken met suiker (bv. frisdrank, fruitsap)]',
#  'Q1.Q29_8.[Hoe regelmatig heb je de onderstaande zaken gegeten of gedronken in de afgelopen 3 maanden? - Zoete dranken zonder suiker (bv. light frisdrank)]',
#  'Q1.Q29_9.[Hoe regelmatig heb je de onderstaande zaken gegeten of gedronken in de afgelopen 3 maanden? - Fruit]',
#  'Q1.Q29_10.[Hoe regelmatig heb je de onderstaande zaken gegeten of gedronken in de afgelopen 3 maanden? - Groenten]',
#  'Q1.Q30_1.[Als je alcohol drinkt, wat drink je dan meestal? (meerdere antwoorden mogelijk) - Selected Choice - Wijn en/of schuimwijn]',
#  'Q1.Q30_2.[Als je alcohol drinkt, wat drink je dan meestal? (meerdere antwoorden mogelijk) - Selected Choice - Bier]',
#  'Q1.Q30_3.[Als je alcohol drinkt, wat drink je dan meestal? (meerdere antwoorden mogelijk) - Selected Choice - Sterke dranken]',
#  'Q1.Q30_4.[Als je alcohol drinkt, wat drink je dan meestal? (meerdere antwoorden mogelijk) - Selected Choice - Ik drink geen alcohol]',
#  'Q1.Q30_5.[Als je alcohol drinkt, wat drink je dan meestal? (meerdere antwoorden mogelijk) - Selected Choice - Andere:]',
#  'Q1.Q30_5_TEXT.[Als je alcohol drinkt, wat drink je dan meestal? (meerdere antwoorden mogelijk) - Andere: - Tekst]',
#  'Q1.Q31_1.[Neem je vitaminen,\nmineralen of andere supplementen? Zo ja, vul je dan ook even in welke? - Selected Choice - Ja, regelmatig doorheen het jaar: welke?]',
#  'Q1.Q31_4.[Neem je vitaminen,\nmineralen of andere supplementen? Zo ja, vul je dan ook even in welke? - Selected Choice - Ja, soms tijdens een bepaalde periode: welke?]',
#  'Q1.Q31_5.[Neem je vitaminen,\nmineralen of andere supplementen? Zo ja, vul je dan ook even in welke? - Selected Choice - Nee]',
#  'Q1.Q31_1_TEXT.[Neem je vitaminen,\nmineralen of andere supplementen? Zo ja, vul je dan ook even in welke? - Ja, regelmatig doorheen het jaar: welke? - Tekst]',
#  'Q1.Q31_4_TEXT.[Neem je vitaminen,\nmineralen of andere supplementen? Zo ja, vul je dan ook even in welke? - Ja, soms tijdens een bepaalde periode: welke? - Tekst]',
#  'Q1.Q31.1.[Indien je in een bepaalde periode vitamines neemt, welke periode?]',
#  'Q1.Q32.[Hoe ben je geboren?]',
#  'Q1.Q33#1_1.[Wat is je bloedgroep en rhesusfactor?\xa0 - Bloedgroep - Bloedgroep]',
#  'Q1.Q33#2_1.[Wat is je bloedgroep en rhesusfactor?\xa0 - Rhesusfactor - Bloedgroep]',
#  'Q1.Q34.[Hoe beoordeel je je algemene\ngezondheidstoestand?]',
#  'Q1.Q35_1.[Heb je ooit één van onderstaande diagnoses\ngekregen van een allergie? (meerdere antwoorden mogelijk) - Selected Choice - Astma]',
#  'Q1.Q35_2.[Heb je ooit één van onderstaande diagnoses\ngekregen van een allergie? (meerdere antwoorden mogelijk) - Selected Choice - Hooikoorts (pollenallergie)]',
#  'Q1.Q35_3.[Heb je ooit één van onderstaande diagnoses\ngekregen van een allergie? (meerdere antwoorden mogelijk) - Selected Choice - Huisstofmijtallergie]',
#  'Q1.Q35_4.[Heb je ooit één van onderstaande diagnoses\ngekregen van een allergie? (meerdere antwoorden mogelijk) - Selected Choice - Dierenallergie, welke?]',
#  'Q1.Q35_5.[Heb je ooit één van onderstaande diagnoses\ngekregen van een allergie? (meerdere antwoorden mogelijk) - Selected Choice - Andere inhalatieallergie:]',
#  'Q1.Q35_6.[Heb je ooit één van onderstaande diagnoses\ngekregen van een allergie? (meerdere antwoorden mogelijk) - Selected Choice - Eczeem]',
#  'Q1.Q35_7.[Heb je ooit één van onderstaande diagnoses\ngekregen van een allergie? (meerdere antwoorden mogelijk) - Selected Choice - Voedselallergie aan:]',
#  'Q1.Q35_8.[Heb je ooit één van onderstaande diagnoses\ngekregen van een allergie? (meerdere antwoorden mogelijk) - Selected Choice - Andere:]',
#  'Q1.Q35_9.[Heb je ooit één van onderstaande diagnoses\ngekregen van een allergie? (meerdere antwoorden mogelijk) - Selected Choice - Nee]',
#  'Q1.Q35_4_TEXT.[Heb je ooit één van onderstaande diagnoses\ngekregen van een allergie? (meerdere antwoorden mogelijk) - Dierenallergie, welke? - Tekst]',
#  'Q1.Q35_5_TEXT.[Heb je ooit één van onderstaande diagnoses\ngekregen van een allergie? (meerdere antwoorden mogelijk) - Andere inhalatieallergie: - Tekst]',
#  'Q1.Q35_7_TEXT.[Heb je ooit één van onderstaande diagnoses\ngekregen van een allergie? (meerdere antwoorden mogelijk) - Voedselallergie aan: - Tekst]',
#  'Q1.Q35_8_TEXT.[Heb je ooit één van onderstaande diagnoses\ngekregen van een allergie? (meerdere antwoorden mogelijk) - Andere: - Tekst]',
#  'Q1.Q35.1.[Indien je astma heb aangeduid. Hoeveel periodes van piepende ademhaling had je de laatste 12 maanden, die niet waren gerelateerd aan een verkoudheid?]',
#  'Q1.Q35.2.[Indien je een allergie hebt. Hoeveel periodes van lopende neus en/of jeukende ogen had je in de laatste 12 maanden, gerelateerd aan een inhalatieallergie?]',
#  'Q1.Q35.3.[Hoe vaak heb je opflakkeringen van eczeem?]',
#  'Q1.Q36_1.[Heb je ooit één van onderstaande diagnoses\ngekregen van een eetstoornis? (meerdere antwoorden mogelijk) - Selected Choice - Anorexia nervosa]',
#  'Q1.Q36_2.[Heb je ooit één van onderstaande diagnoses\ngekregen van een eetstoornis? (meerdere antwoorden mogelijk) - Selected Choice - Boulimia nervosa]',
#  'Q1.Q36_3.[Heb je ooit één van onderstaande diagnoses\ngekregen van een eetstoornis? (meerdere antwoorden mogelijk) - Selected Choice - Binge Eating Disorder]',
#  'Q1.Q36_4.[Heb je ooit één van onderstaande diagnoses\ngekregen van een eetstoornis? (meerdere antwoorden mogelijk) - Selected Choice - Andere]',
#  'Q1.Q36_5.[Heb je ooit één van onderstaande diagnoses\ngekregen van een eetstoornis? (meerdere antwoorden mogelijk) - Selected Choice - Nee]',
#  'Q1.Q36_4_TEXT.[Heb je ooit één van onderstaande diagnoses\ngekregen van een eetstoornis? (meerdere antwoorden mogelijk) - Andere - Tekst]',
#  'Q1.Q37_1.[Heb je één van onderstaande aandoeningen? (Graag de aandoening\nvermelden) (meerdere antwoorden mogelijk) - Selected Choice - Systeem/over heel je lichaam, vb. reuma, artritis, MS, ...]',
#  'Q1.Q37_2.[Heb je één van onderstaande aandoeningen? (Graag de aandoening\nvermelden) (meerdere antwoorden mogelijk) - Selected Choice - Huid, vb. psoriasis, acné, ...]',
#  'Q1.Q37_3.[Heb je één van onderstaande aandoeningen? (Graag de aandoening\nvermelden) (meerdere antwoorden mogelijk) - Selected Choice - Hart/bloedvaten, vb. endocarditis, aneurysma, ...]',
#  'Q1.Q37_4.[Heb je één van onderstaande aandoeningen? (Graag de aandoening\nvermelden) (meerdere antwoorden mogelijk) - Selected Choice - Maag/darmen, vb. ziekte van Crohn, colitis, ...]',
#  'Q1.Q37_5.[Heb je één van onderstaande aandoeningen? (Graag de aandoening\nvermelden) (meerdere antwoorden mogelijk) - Selected Choice - Luchtwegen, vb. astma, allergieën]',
#  'Q1.Q37_6.[Heb je één van onderstaande aandoeningen? (Graag de aandoening\nvermelden) (meerdere antwoorden mogelijk) - Selected Choice - Ogen, vb. glaucoom, cataract, ...]',
#  'Q1.Q37_7.[Heb je één van onderstaande aandoeningen? (Graag de aandoening\nvermelden) (meerdere antwoorden mogelijk) - Selected Choice - Neus-Keel-Oor, vb. chronische rhinosinusitis]',
#  'Q1.Q37_8.[Heb je één van onderstaande aandoeningen? (Graag de aandoening\nvermelden) (meerdere antwoorden mogelijk) - Selected Choice - Hormonaal (vb. schildklier) of diabetes (type1/type2)]',
#  'Q1.Q37_9.[Heb je één van onderstaande aandoeningen? (Graag de aandoening\nvermelden) (meerdere antwoorden mogelijk) - Selected Choice - Voortplantingsstelsel, vb. endometriose]',
#  'Q1.Q37_12.[Heb je één van onderstaande aandoeningen? (Graag de aandoening\nvermelden) (meerdere antwoorden mogelijk) - Selected Choice - Bloed, vb. bloedarmoede, ...]',
#  'Q1.Q37_13.[Heb je één van onderstaande aandoeningen? (Graag de aandoening\nvermelden) (meerdere antwoorden mogelijk) - Selected Choice - Kanker, bv leukemie, borstkanker, ...]',
#  'Q1.Q37_15.[Heb je één van onderstaande aandoeningen? (Graag de aandoening\nvermelden) (meerdere antwoorden mogelijk) - Selected Choice - Andere]',
#  'Q1.Q37_17.[Heb je één van onderstaande aandoeningen? (Graag de aandoening\nvermelden) (meerdere antwoorden mogelijk) - Selected Choice - Nee]',
#  'Q1.Q37_1_TEXT.[Heb je één van onderstaande aandoeningen? (Graag de aandoening\nvermelden) (meerdere antwoorden mogelijk) - Systeem/over heel je lichaam, vb. reuma, artritis, MS, ... - Tekst]',
#  'Q1.Q37_2_TEXT.[Heb je één van onderstaande aandoeningen? (Graag de aandoening\nvermelden) (meerdere antwoorden mogelijk) - Huid, vb. psoriasis, acné, ... - Tekst]',
#  'Q1.Q37_3_TEXT.[Heb je één van onderstaande aandoeningen? (Graag de aandoening\nvermelden) (meerdere antwoorden mogelijk) - Hart/bloedvaten, vb. endocarditis, aneurysma, ... - Tekst]',
#  'Q1.Q37_4_TEXT.[Heb je één van onderstaande aandoeningen? (Graag de aandoening\nvermelden) (meerdere antwoorden mogelijk) - Maag/darmen, vb. ziekte van Crohn, colitis, ... - Tekst]',
#  'Q1.Q37_5_TEXT.[Heb je één van onderstaande aandoeningen? (Graag de aandoening\nvermelden) (meerdere antwoorden mogelijk) - Luchtwegen, vb. astma, allergieën - Tekst]',
#  'Q1.Q37_6_TEXT.[Heb je één van onderstaande aandoeningen? (Graag de aandoening\nvermelden) (meerdere antwoorden mogelijk) - Ogen, vb. glaucoom, cataract, ... - Tekst]',
#  'Q1.Q37_7_TEXT.[Heb je één van onderstaande aandoeningen? (Graag de aandoening\nvermelden) (meerdere antwoorden mogelijk) - Neus-Keel-Oor, vb. chronische rhinosinusitis - Tekst]',
#  'Q1.Q37_8_TEXT.[Heb je één van onderstaande aandoeningen? (Graag de aandoening\nvermelden) (meerdere antwoorden mogelijk) - Hormonaal (vb. schildklier) of diabetes (type1/type2) - Tekst]',
#  'Q1.Q37_9_TEXT.[Heb je één van onderstaande aandoeningen? (Graag de aandoening\nvermelden) (meerdere antwoorden mogelijk) - Voortplantingsstelsel, vb. endometriose - Tekst]',
#  'Q1.Q37_12_TEXT.[Heb je één van onderstaande aandoeningen? (Graag de aandoening\nvermelden) (meerdere antwoorden mogelijk) - Bloed, vb. bloedarmoede, ... - Tekst]',
#  'Q1.Q37_13_TEXT.[Heb je één van onderstaande aandoeningen? (Graag de aandoening\nvermelden) (meerdere antwoorden mogelijk) - Kanker, bv leukemie, borstkanker, ... - Tekst]',
#  'Q1.Q37_15_TEXT.[Heb je één van onderstaande aandoeningen? (Graag de aandoening\nvermelden) (meerdere antwoorden mogelijk) - Andere - Tekst]',
#  'Q1.Q37.1.[Indien je kanker hebt aangeduid. Hoelang geleden was je diagnose? - Selected Choice]',
#  'Q1.Q37.1_2_TEXT.[Indien je kanker hebt aangeduid. Hoelang geleden was je diagnose? - Jaren - Tekst]',
#  'Q1.Q37.1_3_TEXT.[Indien je kanker hebt aangeduid. Hoelang geleden was je diagnose? - Maanden - Tekst]',
#  'Q1.Q38.[Ben je lactose-intolerant?]',
#  'Q1.Q39.[Heb je een glutenallergie?]',
#  'Q1.Q40.[Heb je in de afgelopen drie maanden een antibiotica- of antimycotica[1]-behandeling gehad (ook\nvaginale antibiotica en antimycotica zoals bv. gynodaktarin melden aub)?\n\n\n\n\n\n\n\n\n\n\n[1] Antimycotica = geneesmiddelen met een\nschimmelwerende (fungistatische) of schimmeldodende (fungicide) werking vb.\nDaktarin, Lamisil, Canesten,… - Selected Choice]',
#  'Q1.Q40_1_TEXT.[Heb je in de afgelopen drie maanden een antibiotica- of antimycotica[1]-behandeling gehad (ook\nvaginale antibiotica en antimycotica zoals bv. gynodaktarin melden aub)?\n\n\n\n\n\n\n\n\n\n\n[1] Antimycotica = geneesmiddelen met een\nschimmelwerende (fungistatische) of schimmeldodende (fungicide) werking vb.\nDaktarin, Lamisil, Canesten,… - Ja, hoe vaak? - Tekst]',
#  'Q1.Q41.[Wanneer vond je laatste antibioticabehandeling\n(ongeveer) plaats?]',
#  'Q1.Q42.[Nam je de afgelopen drie maanden medicatie op voorschrift in? Zo ja, kan je aangeven om hoeveel verschillende producten het ging? - Selected Choice]',
#  'Q1.Q42_1_TEXT.[Nam je de afgelopen drie maanden medicatie op voorschrift in? Zo ja, kan je aangeven om hoeveel verschillende producten het ging? - Ja - Tekst]',
#  'Q1.Q42.1_1_1.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 1 - Naam]',
#  'Q1.Q42.1_1_2.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 1 - Dosis]',
#  'Q1.Q42.1_1_3.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 1 - Startdatum]',
#  'Q1.Q42.1_1_4.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 1 - Stopdatum]',
#  'Q1.Q42.1_1_5.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 1 - Reden]',
#  'Q1.Q42.1_2_1.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 2 - Naam]',
#  'Q1.Q42.1_2_2.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 2 - Dosis]',
#  'Q1.Q42.1_2_3.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 2 - Startdatum]',
#  'Q1.Q42.1_2_4.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 2 - Stopdatum]',
#  'Q1.Q42.1_2_5.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 2 - Reden]',
#  'Q1.Q42.1_3_1.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 3 - Naam]',
#  'Q1.Q42.1_3_2.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 3 - Dosis]',
#  'Q1.Q42.1_3_3.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 3 - Startdatum]',
#  'Q1.Q42.1_3_4.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 3 - Stopdatum]',
#  'Q1.Q42.1_3_5.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 3 - Reden]',
#  'Q1.Q42.1_4_1.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 4 - Naam]',
#  'Q1.Q42.1_4_2.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 4 - Dosis]',
#  'Q1.Q42.1_4_3.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 4 - Startdatum]',
#  'Q1.Q42.1_4_4.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 4 - Stopdatum]',
#  'Q1.Q42.1_4_5.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 4 - Reden]',
#  'Q1.Q42.1_5_1.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 5 - Naam]',
#  'Q1.Q42.1_5_2.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 5 - Dosis]',
#  'Q1.Q42.1_5_3.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 5 - Startdatum]',
#  'Q1.Q42.1_5_4.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 5 - Stopdatum]',
#  'Q1.Q42.1_5_5.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 5 - Reden]',
#  'Q1.Q42.1_6_1.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 6 - Naam]',
#  'Q1.Q42.1_6_2.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 6 - Dosis]',
#  'Q1.Q42.1_6_3.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 6 - Startdatum]',
#  'Q1.Q42.1_6_4.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 6 - Stopdatum]',
#  'Q1.Q42.1_6_5.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 6 - Reden]',
#  'Q1.Q42.1_7_1.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 7 - Naam]',
#  'Q1.Q42.1_7_2.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 7 - Dosis]',
#  'Q1.Q42.1_7_3.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 7 - Startdatum]',
#  'Q1.Q42.1_7_4.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 7 - Stopdatum]',
#  'Q1.Q42.1_7_5.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 7 - Reden]',
#  'Q1.Q42.1_8_1.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 8 - Naam]',
#  'Q1.Q42.1_8_2.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 8 - Dosis]',
#  'Q1.Q42.1_8_3.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 8 - Startdatum]',
#  'Q1.Q42.1_8_4.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 8 - Stopdatum]',
#  'Q1.Q42.1_8_5.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 8 - Reden]',
#  'Q1.Q42.1_9_1.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 9 - Naam]',
#  'Q1.Q42.1_9_2.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 9 - Dosis]',
#  'Q1.Q42.1_9_3.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 9 - Startdatum]',
#  'Q1.Q42.1_9_4.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 9 - Stopdatum]',
#  'Q1.Q42.1_9_5.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 9 - Reden]',
#  'Q1.Q42.1_10_1.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 10 - Naam]',
#  'Q1.Q42.1_10_2.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 10 - Dosis]',
#  'Q1.Q42.1_10_3.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 10 - Startdatum]',
#  'Q1.Q42.1_10_4.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 10 - Stopdatum]',
#  'Q1.Q42.1_10_5.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 10 - Reden]',
#  'Q1.Q42.1_11_1.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 11 - Naam]',
#  'Q1.Q42.1_11_2.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 11 - Dosis]',
#  'Q1.Q42.1_11_3.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 11 - Startdatum]',
#  'Q1.Q42.1_11_4.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 11 - Stopdatum]',
#  'Q1.Q42.1_11_5.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 11 - Reden]',
#  'Q1.Q42.1_12_1.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 12 - Naam]',
#  'Q1.Q42.1_12_2.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 12 - Dosis]',
#  'Q1.Q42.1_12_3.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 12 - Startdatum]',
#  'Q1.Q42.1_12_4.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 12 - Stopdatum]',
#  'Q1.Q42.1_12_5.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 12 - Reden]',
#  'Q1.Q42.1_13_1.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 13 - Naam]',
#  'Q1.Q42.1_13_2.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 13 - Dosis]',
#  'Q1.Q42.1_13_3.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 13 - Startdatum]',
#  'Q1.Q42.1_13_4.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 13 - Stopdatum]',
#  'Q1.Q42.1_13_5.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 13 - Reden]',
#  'Q1.Q42.1_14_1.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 14 - Naam]',
#  'Q1.Q42.1_14_2.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 14 - Dosis]',
#  'Q1.Q42.1_14_3.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 14 - Startdatum]',
#  'Q1.Q42.1_14_4.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 14 - Stopdatum]',
#  'Q1.Q42.1_14_5.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 14 - Reden]',
#  'Q1.Q42.1_15_1.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 15 - Naam]',
#  'Q1.Q42.1_15_2.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 15 - Dosis]',
#  'Q1.Q42.1_15_3.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 15 - Startdatum]',
#  'Q1.Q42.1_15_4.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 15 - Stopdatum]',
#  'Q1.Q42.1_15_5.[Vul in dit overzicht de medicatie op voorschrift in die je de voorbije drie maanden hebt gebruikt - 15 - Reden]',
#  'Q1.Q43.[Ben je de laatste 12 maanden naar de tandarts geweest?]',
#  'Q1.Q44.[Heb je de laatste 12 maanden last gehad van regelmatig bloedend tandvlees?]',
#  'Q1.Q45.[Heb je de afgelopen 12 maanden last gehad van cariës of gaatjes?]',
#  'Q1.Q46_1.[Hoe voelde je je de afgelopen vier weken? - Voelde je je erg zenuwachtig?]',
#  'Q1.Q46_2.[Hoe voelde je je de afgelopen vier weken? - Zat je zo erg in de put dat niets je kon opvrolijken?]',
#  'Q1.Q46_3.[Hoe voelde je je de afgelopen vier weken? - Voelde je je kalm en rustig?]',
#  'Q1.Q46_4.[Hoe voelde je je de afgelopen vier weken? - Voelde je je neerslachtig en somber?]',
#  'Q1.Q46_5.[Hoe voelde je je de afgelopen vier weken? - Voelde je je gelukkig?]',
#  'Q1.Q46_6.[Hoe voelde je je de afgelopen vier weken? - Voelde je je gestresseerd?]',
#  'Q1.Q47.[Heb je de afgelopen drie maanden één of meerdere seksuele\npartner(s) gehad? - Selected Choice]',
#  'Q1.Q47_2_TEXT.[Heb je de afgelopen drie maanden één of meerdere seksuele\npartner(s) gehad? - Ja, meerdere vaste partners: hoeveel? - Tekst]',
#  'Q1.Q47_3_TEXT.[Heb je de afgelopen drie maanden één of meerdere seksuele\npartner(s) gehad? - Ja, wisselende partners: hoeveel? - Tekst]',
#  'Q1.Q47.1.[Indien ja, was dit seksueel contact met:]',
#  'Q1.Q47.2_1.[Welke seksuele handelingen heb je ontvangen in de afgelopen drie maanden? (meerdere antwoorden mogelijk) - Selected Choice - Manuele seks]',
#  'Q1.Q47.2_2.[Welke seksuele handelingen heb je ontvangen in de afgelopen drie maanden? (meerdere antwoorden mogelijk) - Selected Choice - Orale seks]',
#  'Q1.Q47.2_3.[Welke seksuele handelingen heb je ontvangen in de afgelopen drie maanden? (meerdere antwoorden mogelijk) - Selected Choice - Vaginale penetratie met vingers]',
#  'Q1.Q47.2_4.[Welke seksuele handelingen heb je ontvangen in de afgelopen drie maanden? (meerdere antwoorden mogelijk) - Selected Choice - Vaginale penetratie met penis]',
#  'Q1.Q47.2_5.[Welke seksuele handelingen heb je ontvangen in de afgelopen drie maanden? (meerdere antwoorden mogelijk) - Selected Choice - Vaginale penetratie met speeltjes]',
#  'Q1.Q47.2_6.[Welke seksuele handelingen heb je ontvangen in de afgelopen drie maanden? (meerdere antwoorden mogelijk) - Selected Choice - Vaginale penetratie met andere:]',
#  'Q1.Q47.2_7.[Welke seksuele handelingen heb je ontvangen in de afgelopen drie maanden? (meerdere antwoorden mogelijk) - Selected Choice - Anale seks]',
#  'Q1.Q47.2_8.[Welke seksuele handelingen heb je ontvangen in de afgelopen drie maanden? (meerdere antwoorden mogelijk) - Selected Choice - Andere:]',
#  'Q1.Q47.2_9.[Welke seksuele handelingen heb je ontvangen in de afgelopen drie maanden? (meerdere antwoorden mogelijk) - Selected Choice - Geen]',
#  'Q1.Q47.2_6_TEXT.[Welke seksuele handelingen heb je ontvangen in de afgelopen drie maanden? (meerdere antwoorden mogelijk) - Vaginale penetratie met andere: - Tekst]',
#  'Q1.Q47.2_8_TEXT.[Welke seksuele handelingen heb je ontvangen in de afgelopen drie maanden? (meerdere antwoorden mogelijk) - Andere: - Tekst]',
#  'Q1.Q48_1.[Welke seksuele handelingen heb je uitgevoerd in de afgelopen drie maanden? (meerdere antwoorden mogelijk) - Selected Choice - Manuele seks]',
#  'Q1.Q48_2.[Welke seksuele handelingen heb je uitgevoerd in de afgelopen drie maanden? (meerdere antwoorden mogelijk) - Selected Choice - Orale seks]',
#  'Q1.Q48_3.[Welke seksuele handelingen heb je uitgevoerd in de afgelopen drie maanden? (meerdere antwoorden mogelijk) - Selected Choice - Vaginale penetratie met vingers]',
#  'Q1.Q48_4.[Welke seksuele handelingen heb je uitgevoerd in de afgelopen drie maanden? (meerdere antwoorden mogelijk) - Selected Choice - Vaginale penetratie met speeltjes]',
#  'Q1.Q48_5.[Welke seksuele handelingen heb je uitgevoerd in de afgelopen drie maanden? (meerdere antwoorden mogelijk) - Selected Choice - Vaginale penetratie met andere:]',
#  'Q1.Q48_6.[Welke seksuele handelingen heb je uitgevoerd in de afgelopen drie maanden? (meerdere antwoorden mogelijk) - Selected Choice - Anale seks]',
#  'Q1.Q48_7.[Welke seksuele handelingen heb je uitgevoerd in de afgelopen drie maanden? (meerdere antwoorden mogelijk) - Selected Choice - Andere:]',
#  'Q1.Q48_8.[Welke seksuele handelingen heb je uitgevoerd in de afgelopen drie maanden? (meerdere antwoorden mogelijk) - Selected Choice - Geen]',
#  'Q1.Q48_5_TEXT.[Welke seksuele handelingen heb je uitgevoerd in de afgelopen drie maanden? (meerdere antwoorden mogelijk) - Vaginale penetratie met andere: - Tekst]',
#  'Q1.Q48_7_TEXT.[Welke seksuele handelingen heb je uitgevoerd in de afgelopen drie maanden? (meerdere antwoorden mogelijk) - Andere: - Tekst]',
#  'Q1.Q48.1.[Heb je de afgelopen drie maanden vaginale seks gehad en zo ja, hoe frequent?]',
#  'Q1.Q48.2.[Heb je vaginale seks gehad tijdens je maandelijkse bloeding in de afgelopen 3 maanden?]',
#  'Q1.Q49.[Heb je ooit actief geprobeerd om zwanger te worden?]',
#  'Q1.Q49.1.[Heb je toen problemen ondervonden bij het vervullen van je zwangerschapswens?]',
#  'Q1.Q49.2.[Ben je hiervoor naar je huisarts/gynaecoloog geweest?]',
#  'Q1.Q49.3_1.[Is er voor jou ooit een vruchtbaarheidstraject\nopgestart? (meerdere antwoorden zijn mogelijk) - Selected Choice - Ja, omwille van mijn verminderde vruchtbaarheid met gekende oorzaak, namelijk:]',
#  'Q1.Q49.3_2.[Is er voor jou ooit een vruchtbaarheidstraject\nopgestart? (meerdere antwoorden zijn mogelijk) - Selected Choice - Ja, omwille van verminderde vruchtbaarheid bij mijn partner]',
#  'Q1.Q49.3_3.[Is er voor jou ooit een vruchtbaarheidstraject\nopgestart? (meerdere antwoorden zijn mogelijk) - Selected Choice - Ja, omwille van onverklaarde verminderde vruchtbaarheid]',
#  'Q1.Q49.3_4.[Is er voor jou ooit een vruchtbaarheidstraject\nopgestart? (meerdere antwoorden zijn mogelijk) - Selected Choice - Ja, omdat ik en mijn vrouwelijke partner moeder wil(den) worden]',
#  'Q1.Q49.3_5.[Is er voor jou ooit een vruchtbaarheidstraject\nopgestart? (meerdere antwoorden zijn mogelijk) - Selected Choice - Ja, omdat ik zonder partner moeder wil(de) worden]',
#  'Q1.Q49.3_6.[Is er voor jou ooit een vruchtbaarheidstraject\nopgestart? (meerdere antwoorden zijn mogelijk) - Selected Choice - Ja, omwille van een andere reden:]',
#  'Q1.Q49.3_7.[Is er voor jou ooit een vruchtbaarheidstraject\nopgestart? (meerdere antwoorden zijn mogelijk) - Selected Choice - Nee]',
#  'Q1.Q49.3_1_TEXT.[Is er voor jou ooit een vruchtbaarheidstraject\nopgestart? (meerdere antwoorden zijn mogelijk) - Ja, omwille van mijn verminderde vruchtbaarheid met gekende oorzaak, namelijk: - Tekst]',
#  'Q1.Q49.3_6_TEXT.[Is er voor jou ooit een vruchtbaarheidstraject\nopgestart? (meerdere antwoorden zijn mogelijk) - Ja, omwille van een andere reden: - Tekst]',
#  'Q1.Q49.4_1.[Indien je een vruchtbaarheidstraject gevolgd zou hebben, welk(e) type(s) traject(en) heb je gevolgd? (meerdere antwoorden zijn mogelijk) - Selected Choice - Hormoontherapie ]',
#  'Q1.Q49.4_2.[Indien je een vruchtbaarheidstraject gevolgd zou hebben, welk(e) type(s) traject(en) heb je gevolgd? (meerdere antwoorden zijn mogelijk) - Selected Choice - Kunstmatige inseminatie]',
#  'Q1.Q49.4_3.[Indien je een vruchtbaarheidstraject gevolgd zou hebben, welk(e) type(s) traject(en) heb je gevolgd? (meerdere antwoorden zijn mogelijk) - Selected Choice - In vitro fertilisatie (IVF)]',
#  'Q1.Q49.4_4.[Indien je een vruchtbaarheidstraject gevolgd zou hebben, welk(e) type(s) traject(en) heb je gevolgd? (meerdere antwoorden zijn mogelijk) - Selected Choice - Intracytoplasmatische sperma-injectie (ICSI)]',
#  'Q1.Q49.4_5.[Indien je een vruchtbaarheidstraject gevolgd zou hebben, welk(e) type(s) traject(en) heb je gevolgd? (meerdere antwoorden zijn mogelijk) - Selected Choice - Andere:]',
#  'Q1.Q49.4_5_TEXT.[Indien je een vruchtbaarheidstraject gevolgd zou hebben, welk(e) type(s) traject(en) heb je gevolgd? (meerdere antwoorden zijn mogelijk) - Andere: - Tekst]',
#  'Q1.Q49.5_1.[Q49.5 - Hoe vaak heb je zo’n traject doorlopen?]',
#  'Q1.Q49.5_2.[Q49.5 - Hoeveel trajecten/cycli hiervan resulteerden in een zwangerschap?]',
#  'Q1.Q49.5_3.[Q49.5 - Hoeveel trajecten/cycli hiervan resulteerden in de geboorte van een kind?]',
#  'Q1.Q50.[Hoeveel keer was je al zwanger?]',
#  'Q1.Q50.1#1_1.[Geef in de onderstaande tabel per zwangerschap meer uitleg.\xa0Indien de laatste kolom niet van toep... - Was de zwangerschap gepland? - Zwangerschap 1]',
#  'Q1.Q50.1#1_2.[Geef in de onderstaande tabel per zwangerschap meer uitleg.\xa0Indien de laatste kolom niet van toep... - Was de zwangerschap gepland? - 2]',
#  'Q1.Q50.1#1_3.[Geef in de onderstaande tabel per zwangerschap meer uitleg.\xa0Indien de laatste kolom niet van toep... - Was de zwangerschap gepland? - 3]',
#  'Q1.Q50.1#1_4.[Geef in de onderstaande tabel per zwangerschap meer uitleg.\xa0Indien de laatste kolom niet van toep... - Was de zwangerschap gepland? - 4]',
#  'Q1.Q50.1#1_5.[Geef in de onderstaande tabel per zwangerschap meer uitleg.\xa0Indien de laatste kolom niet van toep... - Was de zwangerschap gepland? - 5]',
#  'Q1.Q50.1#1_6.[Geef in de onderstaande tabel per zwangerschap meer uitleg.\xa0Indien de laatste kolom niet van toep... - Was de zwangerschap gepland? - 6]',
#  'Q1.Q50.1#1_7.[Geef in de onderstaande tabel per zwangerschap meer uitleg.\xa0Indien de laatste kolom niet van toep... - Was de zwangerschap gepland? - 7]',
#  'Q1.Q50.1#1_8.[Geef in de onderstaande tabel per zwangerschap meer uitleg.\xa0Indien de laatste kolom niet van toep... - Was de zwangerschap gepland? - 8]',
#  'Q1.Q50.1#1_9.[Geef in de onderstaande tabel per zwangerschap meer uitleg.\xa0Indien de laatste kolom niet van toep... - Was de zwangerschap gepland? - 9]',
#  'Q1.Q50.1#1_10.[Geef in de onderstaande tabel per zwangerschap meer uitleg.\xa0Indien de laatste kolom niet van toep... - Was de zwangerschap gepland? - 10]',
#  'Q1.Q50.1#1_11.[Geef in de onderstaande tabel per zwangerschap meer uitleg.\xa0Indien de laatste kolom niet van toep... - Was de zwangerschap gepland? - 11]',
# ...
#  'Q2.Q25_3.[Welke middelden heb je in de afgelopen maand gebruikt om niet\nzwanger te worden? Gelieve ook het merk te geven. (Meerdere antwoorden mogelijk) - Selected Choice - Prikpil:]',
#  'Q2.Q25_4.[Welke middelden heb je in de afgelopen maand gebruikt om niet\nzwanger te worden? Gelieve ook het merk te geven. (Meerdere antwoorden mogelijk) - Selected Choice - Anticonceptiepleister (bv. Evra):]',
#  'Q2.Q25_5.[Welke middelden heb je in de afgelopen maand gebruikt om niet\nzwanger te worden? Gelieve ook het merk te geven. (Meerdere antwoorden mogelijk) - Selected Choice - Anticonceptiering (bv. Nuvaring):]',
#  'Q2.Q25_6.[Welke middelden heb je in de afgelopen maand gebruikt om niet\nzwanger te worden? Gelieve ook het merk te geven. (Meerdere antwoorden mogelijk) - Selected Choice - Hormonaal implantaat (bv. Implanon):]',
#  'Q2.Q25_7.[Welke middelden heb je in de afgelopen maand gebruikt om niet\nzwanger te worden? Gelieve ook het merk te geven. (Meerdere antwoorden mogelijk) - Selected Choice - Hormoonspiraal (bv. Mirena):]',
#  'Q2.Q25_8.[Welke middelden heb je in de afgelopen maand gebruikt om niet\nzwanger te worden? Gelieve ook het merk te geven. (Meerdere antwoorden mogelijk) - Selected Choice - Koperspiraal:]',
#  'Q2.Q25_9.[Welke middelden heb je in de afgelopen maand gebruikt om niet\nzwanger te worden? Gelieve ook het merk te geven. (Meerdere antwoorden mogelijk) - Selected Choice - Condoom:]',
#  'Q2.Q25_10.[Welke middelden heb je in de afgelopen maand gebruikt om niet\nzwanger te worden? Gelieve ook het merk te geven. (Meerdere antwoorden mogelijk) - Selected Choice - Pessarium (= rubber koepeltje):]',
#  'Q2.Q25_11.[Welke middelden heb je in de afgelopen maand gebruikt om niet\nzwanger te worden? Gelieve ook het merk te geven. (Meerdere antwoorden mogelijk) - Selected Choice - Periodieke onthouding (= niet vrijen in vruchtbare periode)]',
#  'Q2.Q25_12.[Welke middelden heb je in de afgelopen maand gebruikt om niet\nzwanger te worden? Gelieve ook het merk te geven. (Meerdere antwoorden mogelijk) - Selected Choice - Coitus interruptus (= penis terugtrekken voor zaadlozing)]',
#  'Q2.Q25_14.[Welke middelden heb je in de afgelopen maand gebruikt om niet\nzwanger te worden? Gelieve ook het merk te geven. (Meerdere antwoorden mogelijk) - Selected Choice - Andere:]',
#  'Q2.Q25_15.[Welke middelden heb je in de afgelopen maand gebruikt om niet\nzwanger te worden? Gelieve ook het merk te geven. (Meerdere antwoorden mogelijk) - Selected Choice - Geen]',
#  'Q2.Q25_1_TEXT.[Welke middelden heb je in de afgelopen maand gebruikt om niet\nzwanger te worden? Gelieve ook het merk te geven. (Meerdere antwoorden mogelijk) - Anticonceptiepil: - tekst]',
#  'Q2.Q25_2_TEXT.[Welke middelden heb je in de afgelopen maand gebruikt om niet\nzwanger te worden? Gelieve ook het merk te geven. (Meerdere antwoorden mogelijk) - Minipil: - tekst]',
#  'Q2.Q25_3_TEXT.[Welke middelden heb je in de afgelopen maand gebruikt om niet\nzwanger te worden? Gelieve ook het merk te geven. (Meerdere antwoorden mogelijk) - Prikpil: - tekst]',
#  'Q2.Q25_4_TEXT.[Welke middelden heb je in de afgelopen maand gebruikt om niet\nzwanger te worden? Gelieve ook het merk te geven. (Meerdere antwoorden mogelijk) - Anticonceptiepleister (bv. Evra): - tekst]',
#  'Q2.Q25_5_TEXT.[Welke middelden heb je in de afgelopen maand gebruikt om niet\nzwanger te worden? Gelieve ook het merk te geven. (Meerdere antwoorden mogelijk) - Anticonceptiering (bv. Nuvaring): - tekst]',
#  'Q2.Q25_6_TEXT.[Welke middelden heb je in de afgelopen maand gebruikt om niet\nzwanger te worden? Gelieve ook het merk te geven. (Meerdere antwoorden mogelijk) - Hormonaal implantaat (bv. Implanon): - tekst]',
#  'Q2.Q25_7_TEXT.[Welke middelden heb je in de afgelopen maand gebruikt om niet\nzwanger te worden? Gelieve ook het merk te geven. (Meerdere antwoorden mogelijk) - Hormoonspiraal (bv. Mirena): - tekst]',
#  'Q2.Q25_8_TEXT.[Welke middelden heb je in de afgelopen maand gebruikt om niet\nzwanger te worden? Gelieve ook het merk te geven. (Meerdere antwoorden mogelijk) - Koperspiraal: - tekst]',
#  'Q2.Q25_9_TEXT.[Welke middelden heb je in de afgelopen maand gebruikt om niet\nzwanger te worden? Gelieve ook het merk te geven. (Meerdere antwoorden mogelijk) - Condoom: - tekst]',
#  'Q2.Q25_10_TEXT.[Welke middelden heb je in de afgelopen maand gebruikt om niet\nzwanger te worden? Gelieve ook het merk te geven. (Meerdere antwoorden mogelijk) - Pessarium (= rubber koepeltje): - tekst]',
#  'Q2.Q25_14_TEXT.[Welke middelden heb je in de afgelopen maand gebruikt om niet\nzwanger te worden? Gelieve ook het merk te geven. (Meerdere antwoorden mogelijk) - Andere: - tekst]',
#  'Q2.Q26_1.[Waarom heb je de afgelopen maand geen anticonceptie methode gebruikt? (Meerdere antwoorden mogelijk) - Selected Choice - Ik had geen seks]',
#  'Q2.Q26_2.[Waarom heb je de afgelopen maand geen anticonceptie methode gebruikt? (Meerdere antwoorden mogelijk) - Selected Choice - Ik had seks maar kon er niet zwanger van worden]',
#  'Q2.Q26_3.[Waarom heb je de afgelopen maand geen anticonceptie methode gebruikt? (Meerdere antwoorden mogelijk) - Selected Choice - Ik ben onvruchtbaar of verminderd vruchtbaar]',
#  'Q2.Q26_4.[Waarom heb je de afgelopen maand geen anticonceptie methode gebruikt? (Meerdere antwoorden mogelijk) - Selected Choice - Ik wil graag zwanger worden]',
#  'Q2.Q26_5.[Waarom heb je de afgelopen maand geen anticonceptie methode gebruikt? (Meerdere antwoorden mogelijk) - Selected Choice - Anticonceptie is duur]',
#  'Q2.Q26_6.[Waarom heb je de afgelopen maand geen anticonceptie methode gebruikt? (Meerdere antwoorden mogelijk) - Selected Choice - Mijn partner is onvruchtbaar of verminderd vruchtbaar]',
#  'Q2.Q26_7.[Waarom heb je de afgelopen maand geen anticonceptie methode gebruikt? (Meerdere antwoorden mogelijk) - Selected Choice - Mijn partner gebruikt anticonceptie]',
#  'Q2.Q26_8.[Waarom heb je de afgelopen maand geen anticonceptie methode gebruikt? (Meerdere antwoorden mogelijk) - Selected Choice - Mijn partner is gesteriliseerd]',
#  'Q2.Q26_9.[Waarom heb je de afgelopen maand geen anticonceptie methode gebruikt? (Meerdere antwoorden mogelijk) - Selected Choice - Ik ben gesteriliseerd]',
#  'Q2.Q26_10.[Waarom heb je de afgelopen maand geen anticonceptie methode gebruikt? (Meerdere antwoorden mogelijk) - Selected Choice - Ik vind het niet leuk te gebruiken]',
#  'Q2.Q26_11.[Waarom heb je de afgelopen maand geen anticonceptie methode gebruikt? (Meerdere antwoorden mogelijk) - Selected Choice - Mijn partner wil geen anticonceptie gebruiken]',
#  'Q2.Q26_12.[Waarom heb je de afgelopen maand geen anticonceptie methode gebruikt? (Meerdere antwoorden mogelijk) - Selected Choice - Het gebruik van anticonceptie is niet de norm binnen mijn cultuur]',
#  'Q2.Q26_13.[Waarom heb je de afgelopen maand geen anticonceptie methode gebruikt? (Meerdere antwoorden mogelijk) - Selected Choice - Ik gebruik geen anticonceptie uit geloofsovertuigingen]',
#  'Q2.Q26_14.[Waarom heb je de afgelopen maand geen anticonceptie methode gebruikt? (Meerdere antwoorden mogelijk) - Selected Choice - Ik heb een vrouwelijke partner]',
#  'Q2.Q26_15.[Waarom heb je de afgelopen maand geen anticonceptie methode gebruikt? (Meerdere antwoorden mogelijk) - Selected Choice - Andere:]',
#  'Q2.Q26_15_TEXT.[Waarom heb je de afgelopen maand geen anticonceptie methode gebruikt? (Meerdere antwoorden mogelijk) - Andere: - tekst]',
#  'Q2.Q27.[Heb je een menstruatie gehad de laatste 6 maanden?]',
#  'Q2.Q28.[Wanneer was de eerste dag van je laatste menstruatie? - Selected Choice]',
#  'Q2.Q28_7_TEXT.[Wanneer was de eerste dag van je laatste menstruatie? - De eerste dag van mijn laatste menstruatie was (dd/mm/jjjj): - tekst]',
#  'Q2.Q29_1.[Heb je de volgende producten de afgelopen 48 uur gebruikt? (Meerdere antwoorden mogelijk) - Selected Choice - Tampon]',
#  'Q2.Q29_2.[Heb je de volgende producten de afgelopen 48 uur gebruikt? (Meerdere antwoorden mogelijk) - Selected Choice - Maandverband]',
#  'Q2.Q29_3.[Heb je de volgende producten de afgelopen 48 uur gebruikt? (Meerdere antwoorden mogelijk) - Selected Choice - Menstruatiecup]',
#  'Q2.Q29_4.[Heb je de volgende producten de afgelopen 48 uur gebruikt? (Meerdere antwoorden mogelijk) - Selected Choice - Inlegkruisje]',
#  'Q2.Q29_5.[Heb je de volgende producten de afgelopen 48 uur gebruikt? (Meerdere antwoorden mogelijk) - Selected Choice - Andere:]',
#  'Q2.Q29_6.[Heb je de volgende producten de afgelopen 48 uur gebruikt? (Meerdere antwoorden mogelijk) - Selected Choice - Nee]',
#  'Q2.Q29_5_TEXT.[Heb je de volgende producten de afgelopen 48 uur gebruikt? (Meerdere antwoorden mogelijk) - Andere: - tekst]',
#  'Q2.Q30_1.[Heb je de laatste week last gehad van één of meerdere klachten aan je vulva of vagina? (Meerdere antwoorden mogelijk) - Selected Choice - Roodheid]',
#  'Q2.Q30_2.[Heb je de laatste week last gehad van één of meerdere klachten aan je vulva of vagina? (Meerdere antwoorden mogelijk) - Selected Choice - Zwelling]',
#  'Q2.Q30_3.[Heb je de laatste week last gehad van één of meerdere klachten aan je vulva of vagina? (Meerdere antwoorden mogelijk) - Selected Choice - Pijn (algemeen)]',
#  'Q2.Q30_4.[Heb je de laatste week last gehad van één of meerdere klachten aan je vulva of vagina? (Meerdere antwoorden mogelijk) - Selected Choice - Jeuk]',
#  'Q2.Q30_5.[Heb je de laatste week last gehad van één of meerdere klachten aan je vulva of vagina? (Meerdere antwoorden mogelijk) - Selected Choice - Branderig gevoel]',
#  'Q2.Q30_6.[Heb je de laatste week last gehad van één of meerdere klachten aan je vulva of vagina? (Meerdere antwoorden mogelijk) - Selected Choice - Toename in vaginale afscheiding (anders dan de normale maandelijkse afscheiding)]',
#  'Q2.Q30_7.[Heb je de laatste week last gehad van één of meerdere klachten aan je vulva of vagina? (Meerdere antwoorden mogelijk) - Selected Choice - Verandering in de vaginale afscheiding (andere kleur, onaangename geur)]',
#  'Q2.Q30_8.[Heb je de laatste week last gehad van één of meerdere klachten aan je vulva of vagina? (Meerdere antwoorden mogelijk) - Selected Choice - Pijn tijdens seksueel contact]',
#  'Q2.Q30_11.[Heb je de laatste week last gehad van één of meerdere klachten aan je vulva of vagina? (Meerdere antwoorden mogelijk) - Selected Choice - Blaasontsteking]',
#  'Q2.Q30_9.[Heb je de laatste week last gehad van één of meerdere klachten aan je vulva of vagina? (Meerdere antwoorden mogelijk) - Selected Choice - Andere:]',
#  'Q2.Q30_10.[Heb je de laatste week last gehad van één of meerdere klachten aan je vulva of vagina? (Meerdere antwoorden mogelijk) - Selected Choice - Nee]',
#  'Q2.Q30_9_TEXT.[Heb je de laatste week last gehad van één of meerdere klachten aan je vulva of vagina? (Meerdere antwoorden mogelijk) - Andere: - tekst]',
#  'Q2.Q31_1.[Welke van de volgende producten heb je de afgelopen 48 uur gebruikt? (Meerdere antwoorden mogelijk) - Vaginaal te gebruiken antimycoticum (vb. Gynodaktarin, Clotrimazol, Canestene, …)]',
#  'Q2.Q31_3.[Welke van de volgende producten heb je de afgelopen 48 uur gebruikt? (Meerdere antwoorden mogelijk) - Vaginale zeep (vb. Lactacyd femina, Multi-Gyn, Sebamed, …)]',
#  'Q2.Q31_4.[Welke van de volgende producten heb je de afgelopen 48 uur gebruikt? (Meerdere antwoorden mogelijk) - Vaginale probiotica (vb Physioflor, Pro-Ven, Mucogyne, Gynoflor, … )]',
#  'Q2.Q31_5.[Welke van de volgende producten heb je de afgelopen 48 uur gebruikt? (Meerdere antwoorden mogelijk) - Geen van bovenstaande]',
#  'Q2.Q32_1.[Welke handelingen heb je de afgelopen 24 uur uitgevoerd? (Meerdere antwoorden mogelijk) - Een bad genomen]',
#  'Q2.Q32_12.[Welke handelingen heb je de afgelopen 24 uur uitgevoerd? (Meerdere antwoorden mogelijk) - Een douche genomen]',
#  'Q2.Q32_13.[Welke handelingen heb je de afgelopen 24 uur uitgevoerd? (Meerdere antwoorden mogelijk) - Enkel vaginale zone gewassen aan de wastafel, bidet, enz.]',
#  'Q2.Q32_14.[Welke handelingen heb je de afgelopen 24 uur uitgevoerd? (Meerdere antwoorden mogelijk) - Vochtige doekjes gebruikt]',
#  'Q2.Q32_15.[Welke handelingen heb je de afgelopen 24 uur uitgevoerd? (Meerdere antwoorden mogelijk) - ‘s Nachts geslapen met je ondergoed aan]',
#  'Q2.Q32_16.[Welke handelingen heb je de afgelopen 24 uur uitgevoerd? (Meerdere antwoorden mogelijk) - Geen van bovenstaande]',
#  'Q2.Q33.[Hoe maak je je vagina proper na een toiletbezoek? - Selected Choice]',
#  'Q2.Q33_7_TEXT.[Hoe maak je je vagina proper na een toiletbezoek? - Andere: - tekst]',
#  'Q2.Q34.[Na een toiletbezoek gebruik ik: - Selected Choice]',
#  'Q2.Q34_7_TEXT.[Na een toiletbezoek gebruik ik: - Andere: - tekst]',
#  'Q2.Q35_1.[Welke onderbroek heb je de afgelopen week gedragen? (Meerdere antwoorden mogelijk) - Selected Choice - Satijn ]',
#  'Q2.Q35_10.[Welke onderbroek heb je de afgelopen week gedragen? (Meerdere antwoorden mogelijk) - Selected Choice - Katoenen ]',
#  'Q2.Q35_11.[Welke onderbroek heb je de afgelopen week gedragen? (Meerdere antwoorden mogelijk) - Selected Choice - Synthetisch, Lycra ]',
#  'Q2.Q35_13.[Welke onderbroek heb je de afgelopen week gedragen? (Meerdere antwoorden mogelijk) - Selected Choice - Synthetisch, Polyamide ]',
#  'Q2.Q35_14.[Welke onderbroek heb je de afgelopen week gedragen? (Meerdere antwoorden mogelijk) - Selected Choice - Synthetisch, Polyester ]',
#  'Q2.Q35_15.[Welke onderbroek heb je de afgelopen week gedragen? (Meerdere antwoorden mogelijk) - Selected Choice - Synthetisch, Geen specificatie]',
#  'Q2.Q35_16.[Welke onderbroek heb je de afgelopen week gedragen? (Meerdere antwoorden mogelijk) - Selected Choice - Bamboe ]',
#  'Q2.Q35_17.[Welke onderbroek heb je de afgelopen week gedragen? (Meerdere antwoorden mogelijk) - Selected Choice - Andere:]',
#  'Q2.Q35_18.[Welke onderbroek heb je de afgelopen week gedragen? (Meerdere antwoorden mogelijk) - Selected Choice - Weet ik niet ]',
#  'Q2.Q35_17_TEXT.[Welke onderbroek heb je de afgelopen week gedragen? (Meerdere antwoorden mogelijk) - Andere: - tekst]',
#  'Q2.Q36.[Hoe regelmatig wissel je jouw onderbroek?]',
#  'Q2.Q37_1.[Ben je de afgelopen 24 uur voor het nemen van je vaginale swab gaan zwemmen? (Meerdere antwoorden mogelijk) - Selected Choice - Ja, Privé zwembad ]',
#  'Q2.Q37_4.[Ben je de afgelopen 24 uur voor het nemen van je vaginale swab gaan zwemmen? (Meerdere antwoorden mogelijk) - Selected Choice - Ja, Openbaar zwembad]',
#  'Q2.Q37_5.[Ben je de afgelopen 24 uur voor het nemen van je vaginale swab gaan zwemmen? (Meerdere antwoorden mogelijk) - Selected Choice - Ja, Zee ]',
#  'Q2.Q37_6.[Ben je de afgelopen 24 uur voor het nemen van je vaginale swab gaan zwemmen? (Meerdere antwoorden mogelijk) - Selected Choice - Ja, Zwemvijver ]',
#  'Q2.Q37_7.[Ben je de afgelopen 24 uur voor het nemen van je vaginale swab gaan zwemmen? (Meerdere antwoorden mogelijk) - Selected Choice - Ja, Rivier ]',
#  'Q2.Q37_8.[Ben je de afgelopen 24 uur voor het nemen van je vaginale swab gaan zwemmen? (Meerdere antwoorden mogelijk) - Selected Choice - Ja, Jacuzzi  ]',
#  'Q2.Q37_9.[Ben je de afgelopen 24 uur voor het nemen van je vaginale swab gaan zwemmen? (Meerdere antwoorden mogelijk) - Selected Choice - Ja, Andere:]',
#  'Q2.Q37_10.[Ben je de afgelopen 24 uur voor het nemen van je vaginale swab gaan zwemmen? (Meerdere antwoorden mogelijk) - Selected Choice - Nee ]',
#  'Q2.Q37_9_TEXT.[Ben je de afgelopen 24 uur voor het nemen van je vaginale swab gaan zwemmen? (Meerdere antwoorden mogelijk) - Ja, Andere: - tekst]',
#  'Q2.Q38.[Heb jij uit eigen ervaring iets dat je wilt meedelen dat je denkt dat belangrijk is voor jouw vaginale gezondheid? Jouw tips & tricks om van een terugkerende vaginale infectie af te geraken? Onderwerpen die jij belangrijk vindt die wij nog niet hebben aangehaald/ bevraagd?]',
#  'Q2.Q39.[Heb je nog andere opmerkingen voor ons na het invullen van deze vragenlijst?]',
#  'A.Isala ID',
#  'A.Arrival date',
#  'A.Sample date',
#  'A.Start menstrual cycle',
#  'A.Intercourse',
#  'A.day_of_cycle',
#  'Q1',
#  'Q2',
#  'A']
